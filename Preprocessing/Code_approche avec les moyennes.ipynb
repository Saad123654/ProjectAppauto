# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from io import StringIO
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## I.Import des données ##

# %%
# Nettoyage manuel des espaces multiples dans le fichier
file_path = 'c:\\Users\\DF6610\\Documents\\ProjectAppauto\\welddb\\welddb.data'
with open(file_path, 'r') as file:
    cleaned_lines = [' '.join(line.split()) for line in file]

# Conversion des lignes nettoyées en DataFrame

data = pd.read_csv(StringIO('\n'.join(cleaned_lines)), sep=' ', na_values='N',header=None)

# %%
# La taille du dataset
print("Le nombre de lignes est: " + str(data.shape[0]))
print("Le nombre de colonnes est: " + str(data.shape[1]))
# Out:
# Le nombre de lignes est: 1652
# Le nombre de colonnes est: 44

# %%
columns = [
    "Carbon concentration / (weight%)",
    "Silicon concentration / (weight%)",
    "Manganese concentration / (weight%)",
    "Sulphur concentration / (weight%)",
    "Phosphorus concentration / (weight%)",
    "Nickel concentration / (weight%)",
    "Chromium concentration / (weight%)",
    "Molybdenum concentration / (weight%)",
    "Vanadium concentration / (weight%)",
    "Copper concentration / (weight%)",
    "Cobalt concentration / (weight%)",
    "Tungsten concentration / (weight%)",
    "Oxygen concentration / parts per million by weight",
    "Titanium concentration / parts per million by weight",
    "Nitrogen concentration / parts per million by weight",
    "Aluminium concentration / parts per million by weight",
    "Boron concentration / parts per million by weight",
    "Niobium concentration / parts per million by weight",
    "Tin concentration / parts per million by weight",
    "Arsenic concentration / parts per million by weight",
    "Antimony concentration / parts per million by weight",
    "Current / A",
    "Voltage / V",
    "AC or DC",
    "Electrode positive or negative",
    "Heat input / kJ/mm",
    "Interpass temperature / deg C",
    "Type of weld",
    "Post weld heat treatment temperature / deg C",
    "Post weld heat treatment time / hours",
    "Yield strength / MPa",
    "Ultimate tensile strength / MPa",
    "Elongation / %",
    "Reduction of Area / %",
    "Charpy temperature / deg C",
    "Charpy impact toughness / J",
    "Hardness / kg/mm2",
    "50 % FATT",
    "Primary ferrite in microstructure / %",
    "Ferrite with second phase / %",
    "Acicular ferrite / %",
    "Martensite / %",
    "Ferrite with carbide aggregate / %",
    "Weld ID"
]

# %%
data.columns=columns
data.head()
# Out:
#    Carbon concentration / (weight%)  Silicon concentration / (weight%)  \
# 0                             0.037                               0.30
# 1                             0.037                               0.30
# 2                             0.037                               0.30
# 3                             0.037                               0.31
# 4                             0.037                               0.31
#
#    Manganese concentration / (weight%) Sulphur concentration / (weight%)  \
# 0                                 0.65                             0.008
# 1                                 0.65                             0.008
# 2                                 0.65                             0.008
# 3                                 1.03                             0.007
# 4                                 1.03                             0.007
#
#    Phosphorus concentration / (weight%)  Nickel concentration / (weight%)  \
# 0                                 0.012                               0.0
# 1                                 0.012                               0.0
# 2                                 0.012                               0.0
# 3                                 0.014                               0.0
# 4                                 0.014                               0.0
#
#    Chromium concentration / (weight%) Molybdenum concentration / (weight%)  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   Vanadium concentration / (weight%) Copper concentration / (weight%)  ...  \
# 0                                NaN                              NaN  ...
# 1                                NaN                              NaN  ...
# 2                                NaN                              NaN  ...
# 3                                NaN                              NaN  ...
# 4                                NaN                              NaN  ...
#
#   Charpy temperature / deg C Charpy impact toughness / J  Hardness / kg/mm2  \
# 0                        NaN                         NaN                NaN
# 1                      -28.0                       100.0                NaN
# 2                      -38.0                       100.0                NaN
# 3                        NaN                         NaN                NaN
# 4                      -48.0                       100.0                NaN
#
#   50 % FATT Primary ferrite in microstructure / %  \
# 0       NaN                                   NaN
# 1       NaN                                   NaN
# 2       NaN                                   NaN
# 3       NaN                                   NaN
# 4       NaN                                    32
#
#   Ferrite with second phase / % Acicular ferrite / % Martensite / %  \
# 0                           NaN                  NaN            NaN
# 1                           NaN                  NaN            NaN
# 2                           NaN                  NaN            NaN
# 3                           NaN                  NaN            NaN
# 4                          28.0                 40.0            0.0
#
#   Ferrite with carbide aggregate / %                        Weld ID
# 0                                NaN    Evans-Ni/CMn-1990/1991-0Aaw
# 1                                NaN  Evans-Ni/CMn-1990/1991-0Aawch
# 2                                NaN    Evans-Ni/CMn-1990/1991-0Aht
# 3                                NaN    Evans-Ni/CMn-1990/1991-0Baw
# 4                                0.0  Evans-Ni/CMn-1990/1991-0Bawch
#
# [5 rows x 44 columns]

# %% [markdown]
# ## II.Groupement ID ##

# %%
# Exemple de DataFrame avec une colonne d'identifiants
data_exple = {
    'ID': ['abcd123', 'abc124', 'abcd125', 'def456', 'def457', 'ghi789', 'ghi7abc']
}

df_exple = pd.DataFrame(data_exple)

# Fonction pour trouver le plus long préfixe commun
def find_longest_common_prefix(ids):
    if not ids:
        return ""
    
    prefix = ids[0]  # Commencer avec le premier identifiant
    for id in ids[1:]:
        while not id.startswith(prefix) and prefix:  # Réduire le préfixe jusqu'à ce qu'il corresponde
            prefix = prefix[:-1]
    return prefix

# Appliquer la fonction à chaque identifiant pour déterminer le préfixe commun
def get_common_prefix(current_id, ids):
    # Chercher le préfixe commun uniquement parmi ceux qui partagent un préfixe similaire
    return find_longest_common_prefix([id for id in ids if id.startswith(current_id[:3])])

# Appliquer la fonction pour chaque ID
df_exple['Common_Prefix'] = df_exple['ID'].apply(lambda x: get_common_prefix(x, df_exple['ID'].tolist()))

df_exple
# Out:
#         ID Common_Prefix
# 0  abcd123           abc
# 1   abc124           abc
# 2  abcd125           abc
# 3   def456         def45
# 4   def457         def45
# 5   ghi789          ghi7
# 6  ghi7abc          ghi7

# %%
data['Common_Prefix'] = data['Weld ID'].apply(lambda x: get_common_prefix(x, data['Weld ID'].tolist()))
data['Common_Prefix'].value_counts()
# Out:
# Common_Prefix
# Evans                      856
# SvenGret-1990-              96
# Pat-1981-                   79
# Mart-                       70
# Gar&K-1975-                 56
# PantK-1990-                 54
# Cunh-1982-                  38
# EvHtIp1979-                 32
# Wolst-1974-                 32
# Icici&-1992-                30
# Chandel&-1985W              23
# KocakP                      21
# Ditt-                       20
# RaiterGonzal-Mo-1989-       18
# Blond&-1984-                18
# PakSven-1990-               17
# Hunt&-Di-1994-              16
# JorgeEtAl-1993-             16
# Stil-TiB-1978-              16
# Wats-1981-                  12
# Kluket-CuMnB-1994-          12
# EPRI-TR-101394s-E9          12
# Es-Souni&-Cu/CMn-1990-      12
# Ga&K-1975II-                10
# Birmingham-MAX3              9
# SurianEtAl-C-1991-0.         8
# Alekseev&-CMnNi-1991-CH      7
# Sw&Rog-1973                  4
# Natsume-1990-                4
# RC81033                      4
# p25-RR82011                  2
# p36-RR82011                  2
# p35-RR82011                  2
# p34-RR82011                  2
# p33-RR82011                  2
# p32-RR82011                  2
# p31-RR82011                  2
# p30-RR82011                  2
# p29-RR82011                  2
# p28-RR82011                  2
# p26-RR82011                  2
# p23-RR82011                  2
# p24-RR82011                  2
# Kik-ng                       2
# p22-RR82011                  2
# p21-RR82011                  2
# p16-RR82011                  2
# p15-RR82011                  2
# p14-RR82011                  2
# p13-RR82011                  2
# p12-RR82011                  2
# p10-RR82011                  2
# p9-RR82011                   2
# Inag&-1966-                  2
# p11-RR82011                  2
# Name: count, dtype: int64

# %%
# df_pivot= pd.pivot_table(df,values=['colonne1',...],index=,aggfunc={'colonne1':"mean",...})

# %% [markdown]
# ## Remarque sur les variables cibles :
# - Hardness / kg/mm² : Une mesure de la dureté du matériau soudé, qui est souvent liée à la qualité de la soudure.
# - Yield strength / MPa ou Ultimate tensile strength / MPa : Ces deux mesures de résistance pourraient également servir de variable cible, car elles reflètent la capacité du matériau à résister à la déformation ou à la rupture.
# - Elongation / etou Reduction of Area / % : Ces mesures sont souvent utilisées pour évaluer la ductilité et la ténacité d'un matériau, ce qui peut être pertinent pour la qualité des soudure
# - Fatt 50%##

# %% [markdown]
# ## Petit nettoyage ##

# %%
# Fonction pour nettoyer les valeurs dans les colonnes numériques
def clean_numeric_values(value):
    if isinstance(value, str) and '<' in value:
        # Enlève le symbole '<' et convertit en float
        return float(value.replace('<', '').strip())
    try:
        # Essaye de convertir la valeur en float directement
        return float(value)
    except (ValueError, TypeError):
        # Si la conversion échoue (ex. si c'est une chaîne non numérique), retourne la valeur originale
        return value

# Appliquer la fonction uniquement aux 21 premières colonnes
data.iloc[:, :21] = data.iloc[:, :21].applymap(clean_numeric_values)

# Affichage des premières lignes du DataFrame nettoyé
data
# Out:
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1325630417.py:14: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data.iloc[:, :21] = data.iloc[:, :21].applymap(clean_numeric_values)
#       Carbon concentration / (weight%)  Silicon concentration / (weight%)  \
# 0                                0.037                               0.30
# 1                                0.037                               0.30
# 2                                0.037                               0.30
# 3                                0.037                               0.31
# 4                                0.037                               0.31
# ...                                ...                                ...
# 1647                             0.100                               0.35
# 1648                             0.088                               0.36
# 1649                             0.090                               0.34
# 1650                             0.092                               0.35
# 1651                             0.180                               0.39
#
#       Manganese concentration / (weight%) Sulphur concentration / (weight%)  \
# 0                                    0.65                             0.008
# 1                                    0.65                             0.008
# 2                                    0.65                             0.008
# 3                                    1.03                             0.007
# 4                                    1.03                             0.007
# ...                                   ...                               ...
# 1647                                 0.90                             0.008
# 1648                                 0.88                             0.008
# 1649                                 0.89                             0.008
# 1650                                 0.90                             0.008
# 1651                                 0.88                             0.008
#
#       Phosphorus concentration / (weight%)  Nickel concentration / (weight%)  \
# 0                                    0.012                              0.00
# 1                                    0.012                              0.00
# 2                                    0.012                              0.00
# 3                                    0.014                              0.00
# 4                                    0.014                              0.00
# ...                                    ...                               ...
# 1647                                 0.016                              0.60
# 1648                                 0.017                              0.57
# 1649                                 0.016                              0.17
# 1650                                 0.016                              0.54
# 1651                                 0.017                              0.18
#
#       Chromium concentration / (weight%) Molybdenum concentration / (weight%)  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 1647                                 8.6                                 0.98
# 1648                                 8.4                                 0.94
# 1649                                 8.2                                 0.94
# 1650                                 8.4                                 0.97
# 1651                                10.2                                 0.94
#
#      Vanadium concentration / (weight%) Copper concentration / (weight%)  ...  \
# 0                                   NaN                              NaN  ...
# 1                                   NaN                              NaN  ...
# 2                                   NaN                              NaN  ...
# 3                                   NaN                              NaN  ...
# 4                                   NaN                              NaN  ...
# ...                                 ...                              ...  ...
# 1647                               0.18                              NaN  ...
# 1648                               0.19                              NaN  ...
# 1649                               0.02                              NaN  ...
# 1650                               0.17                              NaN  ...
# 1651                               0.28                              NaN  ...
#
#      Charpy impact toughness / J Hardness / kg/mm2  50 % FATT  \
# 0                            NaN               NaN        NaN
# 1                          100.0               NaN        NaN
# 2                          100.0               NaN        NaN
# 3                            NaN               NaN        NaN
# 4                          100.0               NaN        NaN
# ...                          ...               ...        ...
# 1647                         NaN               NaN        NaN
# 1648                         NaN               NaN        NaN
# 1649                         NaN               NaN        NaN
# 1650                         NaN               NaN        NaN
# 1651                         NaN               NaN        NaN
#
#      Primary ferrite in microstructure / % Ferrite with second phase / %  \
# 0                                      NaN                           NaN
# 1                                      NaN                           NaN
# 2                                      NaN                           NaN
# 3                                      NaN                           NaN
# 4                                       32                          28.0
# ...                                    ...                           ...
# 1647                                   NaN                           NaN
# 1648                                   NaN                           NaN
# 1649                                   NaN                           NaN
# 1650                                   NaN                           NaN
# 1651                                   NaN                           NaN
#
#      Acicular ferrite / % Martensite / % Ferrite with carbide aggregate / %  \
# 0                     NaN            NaN                                NaN
# 1                     NaN            NaN                                NaN
# 2                     NaN            NaN                                NaN
# 3                     NaN            NaN                                NaN
# 4                    40.0            0.0                                0.0
# ...                   ...            ...                                ...
# 1647                  NaN            NaN                                NaN
# 1648                  NaN            NaN                                NaN
# 1649                  NaN            NaN                                NaN
# 1650                  NaN            NaN                                NaN
# 1651                  NaN            NaN                                NaN
#
#                             Weld ID    Common_Prefix
# 0       Evans-Ni/CMn-1990/1991-0Aaw            Evans
# 1     Evans-Ni/CMn-1990/1991-0Aawch            Evans
# 2       Evans-Ni/CMn-1990/1991-0Aht            Evans
# 3       Evans-Ni/CMn-1990/1991-0Baw            Evans
# 4     Evans-Ni/CMn-1990/1991-0Bawch            Evans
# ...                             ...              ...
# 1647               Birmingham-MAX35  Birmingham-MAX3
# 1648               Birmingham-MAX36  Birmingham-MAX3
# 1649               Birmingham-MAX37  Birmingham-MAX3
# 1650               Birmingham-MAX38  Birmingham-MAX3
# 1651               Birmingham-MAX39  Birmingham-MAX3
#
# [1652 rows x 45 columns]

# %% [markdown]
# ## III.Missing values ##

# %% [markdown]
# ### III.Missing values : vision générale ###

# %%
data.isnull().sum()
# Out:
# Carbon concentration / (weight%)                            0
# Silicon concentration / (weight%)                           0
# Manganese concentration / (weight%)                         0
# Sulphur concentration / (weight%)                           4
# Phosphorus concentration / (weight%)                       10
# Nickel concentration / (weight%)                          955
# Chromium concentration / (weight%)                        868
# Molybdenum concentration / (weight%)                      859
# Vanadium concentration / (weight%)                        724
# Copper concentration / (weight%)                         1074
# Cobalt concentration / (weight%)                         1523
# Tungsten concentration / (weight%)                       1577
# Oxygen concentration / parts per million by weight        396
# Titanium concentration / parts per million by weight      717
# Nitrogen concentration / parts per million by weight      410
# Aluminium concentration / parts per million by weight     747
# Boron concentration / parts per million by weight        1148
# Niobium concentration / parts per million by weight       900
# Tin concentration / parts per million by weight          1356
# Arsenic concentration / parts per million by weight      1418
# Antimony concentration / parts per million by weight     1392
# Current / A                                               248
# Voltage / V                                               248
# AC or DC                                                  215
# Electrode positive or negative                            156
# Heat input / kJ/mm                                          0
# Interpass temperature / deg C                               0
# Type of weld                                                0
# Post weld heat treatment temperature / deg C               13
# Post weld heat treatment time / hours                      13
# Yield strength / MPa                                      872
# Ultimate tensile strength / MPa                           914
# Elongation / %                                            952
# Reduction of Area / %                                     947
# Charpy temperature / deg C                                773
# Charpy impact toughness / J                               773
# Hardness / kg/mm2                                        1514
# 50 % FATT                                                1621
# Primary ferrite in microstructure / %                    1554
# Ferrite with second phase / %                            1562
# Acicular ferrite / %                                     1562
# Martensite / %                                           1563
# Ferrite with carbide aggregate / %                       1563
# Weld ID                                                     0
# Common_Prefix                                               0
# dtype: int64

# %%
df=data

# %% [markdown]
# #### Remarque: Beaucoup de valeurs manquantes ####

# %% [markdown]
# ### III.Missing values :  Sulphur concentration / (weight%) ###

# %%
data[data['Sulphur concentration / (weight%)'].isnull()]
# Out:
#       Carbon concentration / (weight%)  Silicon concentration / (weight%)  \
# 1303                              0.11                               0.18
# 1304                              0.10                               0.17
# 1305                              0.11                               0.17
# 1306                              0.10                               0.16
#
#       Manganese concentration / (weight%) Sulphur concentration / (weight%)  \
# 1303                                 0.70                               NaN
# 1304                                 0.67                               NaN
# 1305                                 0.65                               NaN
# 1306                                 0.61                               NaN
#
#       Phosphorus concentration / (weight%)  Nickel concentration / (weight%)  \
# 1303                                   NaN                              0.13
# 1304                                   NaN                              0.14
# 1305                                   NaN                              0.02
# 1306                                   NaN                              0.02
#
#       Chromium concentration / (weight%) Molybdenum concentration / (weight%)  \
# 1303                                2.28                                 0.27
# 1304                                2.31                                 0.29
# 1305                                2.28                                 0.27
# 1306                                2.27                                 0.27
#
#      Vanadium concentration / (weight%) Copper concentration / (weight%)  ...  \
# 1303                                NaN                              NaN  ...
# 1304                                NaN                              NaN  ...
# 1305                                NaN                              NaN  ...
# 1306                                NaN                              NaN  ...
#
#      Charpy impact toughness / J Hardness / kg/mm2  50 % FATT  \
# 1303                         NaN               NaN        NaN
# 1304                         NaN               NaN        NaN
# 1305                         NaN               NaN        NaN
# 1306                         NaN               NaN        NaN
#
#      Primary ferrite in microstructure / % Ferrite with second phase / %  \
# 1303                                   NaN                           NaN
# 1304                                   NaN                           NaN
# 1305                                   NaN                           NaN
# 1306                                   NaN                           NaN
#
#      Acicular ferrite / % Martensite / % Ferrite with carbide aggregate / %  \
# 1303                  NaN            NaN                                NaN
# 1304                  NaN            NaN                                NaN
# 1305                  NaN            NaN                                NaN
# 1306                  NaN            NaN                                NaN
#
#               Weld ID  Common_Prefix
# 1303  Natsume-1990-hl  Natsume-1990-
# 1304  Natsume-1990-hh  Natsume-1990-
# 1305  Natsume-1990-ll  Natsume-1990-
# 1306  Natsume-1990-lh  Natsume-1990-
#
# [4 rows x 45 columns]

# %%
# Tracer le graphique de distribution
plt.figure(figsize=(30, 6))
sns.histplot(data['Sulphur concentration / (weight%)'], bins=10, kde=True)
plt.title('Distribution de la concentration de soufre')
plt.xlabel('Concentration de soufre / (weight%)')
plt.ylabel('Fréquence')
plt.show()

# %%
df['Sulphur concentration / (weight%)'].fillna(df['Sulphur concentration / (weight%)'].mean(), inplace=True)
# Out:
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1020160495.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Sulphur concentration / (weight%)'].fillna(df['Sulphur concentration / (weight%)'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1020160495.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Sulphur concentration / (weight%)'].fillna(df['Sulphur concentration / (weight%)'].mean(), inplace=True)

# %% [markdown]
# ### III.Missing values :  Phosphorus concentration / (weight%) ###

# %%
df['Phosphorus concentration / (weight%)'].describe()
# Out:
# count    1642.000000
# mean        0.012952
# std         0.019627
# min         0.002000
# 25%         0.007000
# 50%         0.010000
# 75%         0.014000
# max         0.250000
# Name: Phosphorus concentration / (weight%), dtype: float64

# %%
df[df['Phosphorus concentration / (weight%)'].isnull()]
# Out:
#       Carbon concentration / (weight%)  Silicon concentration / (weight%)  \
# 1150                              0.11                               0.38
# 1151                              0.11                               0.37
# 1152                              0.11                               0.38
# 1153                              0.14                               0.38
# 1154                              0.10                               0.38
# 1155                              0.10                               0.39
# 1303                              0.11                               0.18
# 1304                              0.10                               0.17
# 1305                              0.11                               0.17
# 1306                              0.10                               0.16
#
#       Manganese concentration / (weight%)  Sulphur concentration / (weight%)  \
# 1150                                 1.50                           0.029000
# 1151                                 1.52                           0.030000
# 1152                                 1.55                           0.029000
# 1153                                 1.65                           0.028000
# 1154                                 1.58                           0.028000
# 1155                                 1.68                           0.027000
# 1303                                 0.70                           0.009529
# 1304                                 0.67                           0.009529
# 1305                                 0.65                           0.009529
# 1306                                 0.61                           0.009529
#
#       Phosphorus concentration / (weight%)  Nickel concentration / (weight%)  \
# 1150                                   NaN                               NaN
# 1151                                   NaN                               NaN
# 1152                                   NaN                               NaN
# 1153                                   NaN                               NaN
# 1154                                   NaN                               NaN
# 1155                                   NaN                               NaN
# 1303                                   NaN                              0.13
# 1304                                   NaN                              0.14
# 1305                                   NaN                              0.02
# 1306                                   NaN                              0.02
#
#       Chromium concentration / (weight%) Molybdenum concentration / (weight%)  \
# 1150                                 NaN                                  0.0
# 1151                                 NaN                                  0.0
# 1152                                 NaN                                  0.0
# 1153                                 NaN                                  0.5
# 1154                                 NaN                                  0.5
# 1155                                 NaN                                  0.5
# 1303                                2.28                                 0.27
# 1304                                2.31                                 0.29
# 1305                                2.28                                 0.27
# 1306                                2.27                                 0.27
#
#      Vanadium concentration / (weight%) Copper concentration / (weight%)  ...  \
# 1150                              0.005                              NaN  ...
# 1151                               0.05                              NaN  ...
# 1152                               0.09                              NaN  ...
# 1153                              0.005                              NaN  ...
# 1154                               0.06                              NaN  ...
# 1155                               0.08                              NaN  ...
# 1303                                NaN                              NaN  ...
# 1304                                NaN                              NaN  ...
# 1305                                NaN                              NaN  ...
# 1306                                NaN                              NaN  ...
#
#      Charpy impact toughness / J Hardness / kg/mm2  50 % FATT  \
# 1150                         NaN               NaN        NaN
# 1151                         NaN               NaN        NaN
# 1152                         NaN               NaN        NaN
# 1153                         NaN               NaN        NaN
# 1154                         NaN               NaN        NaN
# 1155                         NaN               NaN        NaN
# 1303                         NaN               NaN        NaN
# 1304                         NaN               NaN        NaN
# 1305                         NaN               NaN        NaN
# 1306                         NaN               NaN        NaN
#
#      Primary ferrite in microstructure / % Ferrite with second phase / %  \
# 1150                                   NaN                           NaN
# 1151                                   NaN                           NaN
# 1152                                   NaN                           NaN
# 1153                                   NaN                           NaN
# 1154                                   NaN                           NaN
# 1155                                   NaN                           NaN
# 1303                                   NaN                           NaN
# 1304                                   NaN                           NaN
# 1305                                   NaN                           NaN
# 1306                                   NaN                           NaN
#
#      Acicular ferrite / % Martensite / % Ferrite with carbide aggregate / %  \
# 1150                  NaN            NaN                                NaN
# 1151                  NaN            NaN                                NaN
# 1152                  NaN            NaN                                NaN
# 1153                  NaN            NaN                                NaN
# 1154                  NaN            NaN                                NaN
# 1155                  NaN            NaN                                NaN
# 1303                  NaN            NaN                                NaN
# 1304                  NaN            NaN                                NaN
# 1305                  NaN            NaN                                NaN
# 1306                  NaN            NaN                                NaN
#
#                     Weld ID  Common_Prefix
# 1150  Gar&K-1975-12mmE-26aw    Gar&K-1975-
# 1151  Gar&K-1975-12mmE-27aw    Gar&K-1975-
# 1152  Gar&K-1975-12mmE-28aw    Gar&K-1975-
# 1153  Gar&K-1975-12mmE-29aw    Gar&K-1975-
# 1154  Gar&K-1975-12mmE-30aw    Gar&K-1975-
# 1155  Gar&K-1975-12mmE-31aw    Gar&K-1975-
# 1303        Natsume-1990-hl  Natsume-1990-
# 1304        Natsume-1990-hh  Natsume-1990-
# 1305        Natsume-1990-ll  Natsume-1990-
# 1306        Natsume-1990-lh  Natsume-1990-
#
# [10 rows x 45 columns]

# %%
m = df[df['Common_Prefix'] == 'Gar&K-1975-']['Phosphorus concentration / (weight%)'].mean()

# %%
# Fill NaN values with the mean in the original DataFrame
df.loc[df['Common_Prefix'] == 'Gar&K-1975-', 'Phosphorus concentration / (weight%)'] = df.loc[df['Common_Prefix'] == 'Gar&K-1975-', 'Phosphorus concentration / (weight%)'].fillna(m)

# %%
df['Phosphorus concentration / (weight%)'].fillna(df['Phosphorus concentration / (weight%)'].mean(), inplace=True)
# Out:
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3189484787.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Phosphorus concentration / (weight%)'].fillna(df['Phosphorus concentration / (weight%)'].mean(), inplace=True)

# %% [markdown]
# ### III.Missing values :  other concentrations / (weight%) ###

# %%
df['Nickel concentration / (weight%)'].fillna(df['Nickel concentration / (weight%)'].mean(), inplace=True)
df['Chromium concentration / (weight%)'].fillna(df['Chromium concentration / (weight%)'].mean(), inplace=True)
df['Molybdenum concentration / (weight%)'].fillna(df['Molybdenum concentration / (weight%)'].mean(), inplace=True)
df['Vanadium concentration / (weight%)'].fillna(df['Vanadium concentration / (weight%)'].mean(), inplace=True)
df['Copper concentration / (weight%)'].fillna(df['Copper concentration / (weight%)'].mean(), inplace=True)
df['Cobalt concentration / (weight%)'].fillna(df['Cobalt concentration / (weight%)'].mean(), inplace=True)
df['Tungsten concentration / (weight%)'].fillna(df['Tungsten concentration / (weight%)'].mean(), inplace=True)
df['Oxygen concentration / parts per million by weight'].fillna(df['Oxygen concentration / parts per million by weight'].mean(), inplace=True)
df['Titanium concentration / parts per million by weight'].fillna(df['Titanium concentration / parts per million by weight'].mean(), inplace=True)
# Out:
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Nickel concentration / (weight%)'].fillna(df['Nickel concentration / (weight%)'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Chromium concentration / (weight%)'].fillna(df['Chromium concentration / (weight%)'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Molybdenum concentration / (weight%)'].fillna(df['Molybdenum concentration / (weight%)'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Molybdenum concentration / (weight%)'].fillna(df['Molybdenum concentration / (weight%)'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Vanadium concentration / (weight%)'].fillna(df['Vanadium concentration / (weight%)'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Vanadium concentration / (weight%)'].fillna(df['Vanadium concentration / (weight%)'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Copper concentration / (weight%)'].fillna(df['Copper concentration / (weight%)'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Copper concentration / (weight%)'].fillna(df['Copper concentration / (weight%)'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cobalt concentration / (weight%)'].fillna(df['Cobalt concentration / (weight%)'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Cobalt concentration / (weight%)'].fillna(df['Cobalt concentration / (weight%)'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Tungsten concentration / (weight%)'].fillna(df['Tungsten concentration / (weight%)'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Tungsten concentration / (weight%)'].fillna(df['Tungsten concentration / (weight%)'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Oxygen concentration / parts per million by weight'].fillna(df['Oxygen concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Titanium concentration / parts per million by weight'].fillna(df['Titanium concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\1851643774.py:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Titanium concentration / parts per million by weight'].fillna(df['Titanium concentration / parts per million by weight'].mean(), inplace=True)

# %%
df['Nitrogen concentration / parts per million by weight'].fillna(df['Nitrogen concentration / parts per million by weight'].mean(), inplace=True)
df['Aluminium concentration / parts per million by weight'].fillna(df['Aluminium concentration / parts per million by weight'].mean(), inplace=True)
df['Boron concentration / parts per million by weight'].fillna(df['Boron concentration / parts per million by weight'].mean(), inplace=True)
df['Niobium concentration / parts per million by weight'].fillna(df['Niobium concentration / parts per million by weight'].mean(), inplace=True)
df['Tin concentration / parts per million by weight'].fillna(df['Tin concentration / parts per million by weight'].mean(), inplace=True)
df['Arsenic concentration / parts per million by weight'].fillna(df['Arsenic concentration / parts per million by weight'].mean(), inplace=True)
df['Antimony concentration / parts per million by weight'].fillna(df['Antimony concentration / parts per million by weight'].mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[613], line 1
# ----> 1 df['Nitrogen concentration / parts per million by weight'].fillna(df['Nitrogen concentration / parts per million by weight'].mean(), inplace=True)
#       2 df['Aluminium concentration / parts per million by weight'].fillna(df['Aluminium concentration / parts per million by weight'].mean(), inplace=True)
#       3 df['Boron concentration / parts per million by weight'].fillna(df['Boron concentration / parts per million by weight'].mean(), inplace=True)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6452     # GH#47500 - change to TypeError to match other methods
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\nanops.py:719, in nanmean(values, axis, skipna, mask)
#     716     dtype_count = dtype
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
# Convert to numeric, coercing errors to NaN
df['Nitrogen concentration / parts per million by weight'] = pd.to_numeric(df['Nitrogen concentration / parts per million by weight'], errors='coerce')

# Optionally, drop NaN values if you want to calculate the mean only for valid entries
mean_nitrogen_concentration = df['Nitrogen concentration / parts per million by weight'].mean()
print(mean_nitrogen_concentration)
# Out:
# 113.37869822485207

# %%
df['Nitrogen concentration / parts per million by weight'].fillna(df['Nitrogen concentration / parts per million by weight'].mean(), inplace=True)
df['Aluminium concentration / parts per million by weight'].fillna(df['Aluminium concentration / parts per million by weight'].mean(), inplace=True)
df['Boron concentration / parts per million by weight'].fillna(df['Boron concentration / parts per million by weight'].mean(), inplace=True)
df['Niobium concentration / parts per million by weight'].fillna(df['Niobium concentration / parts per million by weight'].mean(), inplace=True)
df['Tin concentration / parts per million by weight'].fillna(df['Tin concentration / parts per million by weight'].mean(), inplace=True)
df['Arsenic concentration / parts per million by weight'].fillna(df['Arsenic concentration / parts per million by weight'].mean(), inplace=True)
df['Antimony concentration / parts per million by weight'].fillna(df['Antimony concentration / parts per million by weight'].mean(), inplace=True)
# Out:
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3204121392.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Nitrogen concentration / parts per million by weight'].fillna(df['Nitrogen concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3204121392.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Aluminium concentration / parts per million by weight'].fillna(df['Aluminium concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3204121392.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Aluminium concentration / parts per million by weight'].fillna(df['Aluminium concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3204121392.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Boron concentration / parts per million by weight'].fillna(df['Boron concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3204121392.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Boron concentration / parts per million by weight'].fillna(df['Boron concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3204121392.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Niobium concentration / parts per million by weight'].fillna(df['Niobium concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3204121392.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Niobium concentration / parts per million by weight'].fillna(df['Niobium concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3204121392.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Tin concentration / parts per million by weight'].fillna(df['Tin concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3204121392.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Tin concentration / parts per million by weight'].fillna(df['Tin concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3204121392.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Arsenic concentration / parts per million by weight'].fillna(df['Arsenic concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3204121392.py:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Arsenic concentration / parts per million by weight'].fillna(df['Arsenic concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3204121392.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Antimony concentration / parts per million by weight'].fillna(df['Antimony concentration / parts per million by weight'].mean(), inplace=True)
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\3204121392.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Antimony concentration / parts per million by weight'].fillna(df['Antimony concentration / parts per million by weight'].mean(), inplace=True)

# %% [markdown]
# ### III.Missing values :  current & Voltage ###

# %%
df[df['Current / A'].isnull()]['Common_Prefix'].value_counts()
# Out:
# Common_Prefix
# Evans           156
# Cunh-1982-       38
# EvHtIp1979-      32
# Blond&-1984-     18
# Sw&Rog-1973       4
# Name: count, dtype: int64

# %%
evans_c=df[df['Common_Prefix']=='Evans']['Current / A'].mean()
evans_v=df[df['Common_Prefix']=='Evans']['Voltage / V'].mean()

# %%
# Fill NaN values with the mean in the original DataFrame
df.loc[df['Common_Prefix'] == 'Evans', 'Current / A'] = df.loc[df['Common_Prefix'] == 'Evans', 'Current / A'].fillna(evans_c)
df.loc[df['Common_Prefix'] == 'Evans', 'Voltage / V'] = df.loc[df['Common_Prefix'] == 'Evans', 'Voltage / V'].fillna(evans_v)

# %%
df['Current / A']= df['Current / A'].fillna(df['Current / A'].mean())
df['Voltage / V']= df['Voltage / V'].fillna(df['Voltage / V'].mean())

# %% [markdown]
# ### III.Missing values :  AC or DC ###

# %%
df[df['AC or DC'].isnull()]['Common_Prefix'].value_counts()
# Out:
# Common_Prefix
# Evans              156
# Birmingham-MAX3      9
# RC81033              4
# p12-RR82011          2
# p28-RR82011          2
# p11-RR82011          2
# p36-RR82011          2
# p35-RR82011          2
# p34-RR82011          2
# p33-RR82011          2
# p32-RR82011          2
# p31-RR82011          2
# p30-RR82011          2
# p29-RR82011          2
# p26-RR82011          2
# p13-RR82011          2
# p10-RR82011          2
# p25-RR82011          2
# p24-RR82011          2
# p23-RR82011          2
# p22-RR82011          2
# p21-RR82011          2
# p16-RR82011          2
# p15-RR82011          2
# p14-RR82011          2
# p9-RR82011           2
# Name: count, dtype: int64

# %%
df[df['Common_Prefix']=='Evans']['AC or DC'].value_counts()
# Out:
# AC or DC
# DC    696
# AC      4
# Name: count, dtype: int64

# %%
df.loc[df['Common_Prefix'] == 'Evans', 'AC or DC'] = df.loc[df['Common_Prefix'] == 'Evans', 'AC or DC'].fillna('DC')

# %%
df['AC or DC']= df['AC or DC'].fillna('o')

# %% [markdown]
# ### III.Missing values :  Electrode positive ou négative ###

# %%
df[df['Electrode positive or negative'].isnull()]['Common_Prefix'].value_counts()
# Out:
# Common_Prefix
# Evans    156
# Name: count, dtype: int64

# %%
df[df['Common_Prefix']=='Evans']['Electrode positive or negative'].value_counts()
# Out:
# Electrode positive or negative
# +    696
# 0      4
# Name: count, dtype: int64

# %%
df['Electrode positive or negative']= df['Electrode positive or negative'].fillna('+')

# %% [markdown]
# ### III.Missing values :  Post weld heat treatment temperature / deg C et
#
# Post weld heat treatment time / hours  ###

# %%
df[df['Post weld heat treatment time / hours'].isnull()]['Common_Prefix'].value_counts()
# Out:
# Common_Prefix
# Gar&K-1975-    13
# Name: count, dtype: int64

# %%
df[df['Common_Prefix']=='Gar&K-1975-']['Post weld heat treatment temperature / deg C'].mean()
# Out:
# 251.1627906976744

# %%
gark_t=df[df['Common_Prefix']=='Gar&K-1975-']['Post weld heat treatment temperature / deg C'].mean()
gark_time=df[df['Common_Prefix']=='Gar&K-1975-']['Post weld heat treatment time / hours'].mean()

# %%
df['Post weld heat treatment temperature / deg C']= df['Post weld heat treatment temperature / deg C'].fillna(gark_t)
df['Post weld heat treatment time / hours']= df['Post weld heat treatment time / hours'].fillna(gark_time)

# %% [markdown]
# ### III.Missing values : Charpy   ###

# %%
df[df['Charpy impact toughness / J'].isnull()]['Common_Prefix'].value_counts()
# Out:
# Common_Prefix
# Evans                      315
# Gar&K-1975-                 56
# PantK-1990-                 42
# Cunh-1982-                  38
# Wolst-1974-                 32
# KocakP                      21
# RaiterGonzal-Mo-1989-       18
# PakSven-1990-               17
# EvHtIp1979-                 16
# Stil-TiB-1978-              16
# Pat-1981-                   16
# Hunt&-Di-1994-              16
# SvenGret-1990-              16
# Icici&-1992-                14
# Blond&-1984-                12
# EPRI-TR-101394s-E9          12
# Es-Souni&-Cu/CMn-1990-      12
# Ga&K-1975II-                10
# Birmingham-MAX3              9
# Mart-                        7
# Alekseev&-CMnNi-1991-CH      7
# Ditt-                        5
# Natsume-1990-                4
# RC81033                      4
# Chandel&-1985W               4
# Sw&Rog-1973                  4
# p36-RR82011                  2
# p35-RR82011                  2
# p34-RR82011                  2
# p25-RR82011                  2
# p32-RR82011                  2
# p31-RR82011                  2
# p30-RR82011                  2
# p29-RR82011                  2
# p28-RR82011                  2
# p26-RR82011                  2
# p33-RR82011                  2
# p22-RR82011                  2
# p24-RR82011                  2
# p23-RR82011                  2
# p21-RR82011                  2
# p16-RR82011                  2
# p15-RR82011                  2
# p14-RR82011                  2
# p13-RR82011                  2
# p12-RR82011                  2
# p11-RR82011                  2
# p10-RR82011                  2
# p9-RR82011                   2
# Kik-ng                       2
# Inag&-1966-                  2
# Name: count, dtype: int64

# %%
evans_charpyJ=df[df['Common_Prefix']=='Evans']['Charpy impact toughness / J'].mean()
evanc_charpyC=df[df['Common_Prefix']=='Evans']['Charpy temperature / deg C'].mean()

# %%
evans_charpyJ
# Out:
# 85.73382624768946

# %%
df.loc[df['Common_Prefix'] == 'Evans', 'Charpy impact toughness / J'] = df.loc[df['Common_Prefix'] == 'Evans', 'Charpy impact toughness / J'].fillna(evans_charpyJ)
df.loc[df['Common_Prefix'] == 'Evans', 'Charpy temperature / deg C'] = df.loc[df['Common_Prefix'] == 'Evans', 'Charpy temperature / deg C'].fillna(evanc_charpyC)

# %%
pant_charpyJ=df[df['Common_Prefix']=='PantK-1990-']['Charpy impact toughness / J'].mean()
pant_charpyC=df[df['Common_Prefix']=='PantK-1990-']['Charpy temperature / deg C'].mean()

# %%
df.loc[df['Common_Prefix'] == 'PantK-1990-', 'Charpy impact toughness / J'] = df.loc[df['Common_Prefix'] == 'PantK-1990-', 'Charpy impact toughness / J'].fillna(pant_charpyJ)
df.loc[df['Common_Prefix'] == 'PantK-1990-', 'Charpy temperature / deg C'] = df.loc[df['Common_Prefix'] == 'PantK-1990-', 'Charpy temperature / deg C'].fillna(pant_charpyC)

# %%
sven_charpyJ=df[df['Common_Prefix']=='SvenGret-1990-']['Charpy impact toughness / J'].mean()
sven_charpyC=df[df['Common_Prefix']=='SvenGret-1990-']['Charpy temperature / deg C'].mean()

# %%
df.loc[df['Common_Prefix'] == 'SvenGret-1990-', 'Charpy impact toughness / J'] = df.loc[df['Common_Prefix'] == 'SvenGret-1990-', 'Charpy impact toughness / J'].fillna(sven_charpyJ)
df.loc[df['Common_Prefix'] == 'SvenGret-1990-', 'Charpy temperature / deg C'] = df.loc[df['Common_Prefix'] == 'SvenGret-1990-', 'Charpy temperature / deg C'].fillna(sven_charpyC)

# %%
pat_charpyJ=df[df['Common_Prefix']=='Pat-1981-']['Charpy impact toughness / J'].mean()
pat_charpyC=df[df['Common_Prefix']=='Pat-1981-']['Charpy temperature / deg C'].mean()

# %%
df.loc[df['Common_Prefix'] == 'Pat-1981-', 'Charpy impact toughness / J'] = df.loc[df['Common_Prefix'] == 'Pat-1981-', 'Charpy impact toughness / J'].fillna(pat_charpyJ)
df.loc[df['Common_Prefix'] == 'Pat-1981-', 'Charpy temperature / deg C'] = df.loc[df['Common_Prefix'] == 'Pat-1981-', 'Charpy temperature / deg C'].fillna(pat_charpyC)

# %%
df[df['Common_Prefix']=='EvHtIp1979-']['Charpy impact toughness / J'].mean()
# Out:
# 100.0

# %%
evht_charpyJ=df[df['Common_Prefix']=='EvHtIp1979-']['Charpy impact toughness / J'].mean()
evht_charpyC=df[df['Common_Prefix']=='EvHtIp1979-']['Charpy temperature / deg C'].mean()

# %%
df.loc[df['Common_Prefix'] == 'EvHtIp1979-', 'Charpy impact toughness / J'] = df.loc[df['Common_Prefix'] == 'EvHtIp1979-', 'Charpy impact toughness / J'].fillna(evht_charpyJ)
df.loc[df['Common_Prefix'] == 'EvHtIp1979-', 'Charpy temperature / deg C'] = df.loc[df['Common_Prefix'] == 'EvHtIp1979-', 'Charpy temperature / deg C'].fillna(evht_charpyC)

# %%
df[df['Common_Prefix']=='Icici&-1992-']['Charpy impact toughness / J'].mean()
# Out:
# 51.8125

# %%
ici_charpyJ=df[df['Common_Prefix']=='Icici&-1992-']['Charpy impact toughness / J'].mean()
ici_charpyC=df[df['Common_Prefix']=='Icici&-1992-']['Charpy temperature / deg C'].mean()

# %%
df.loc[df['Common_Prefix'] == 'Icici&-1992-', 'Charpy impact toughness / J'] = df.loc[df['Common_Prefix'] == 'Icici&-1992-', 'Charpy impact toughness / J'].fillna(ici_charpyJ)
df.loc[df['Common_Prefix'] == 'Icici&-1992-', 'Charpy temperature / deg C'] = df.loc[df['Common_Prefix'] == 'Icici&-1992-', 'Charpy temperature / deg C'].fillna(ici_charpyC)

# %%
df[df['Common_Prefix']=='Blond&-1984-']['Charpy impact toughness / J'].mean()
# Out:
# 69.0

# %%
bld_charpyJ=df[df['Common_Prefix']=='Blond&-1984-']['Charpy impact toughness / J'].mean()
bld_charpyC=df[df['Common_Prefix']=='Blond&-1984-']['Charpy temperature / deg C'].mean()

# %%
df.loc[df['Common_Prefix'] == 'Blond&-1984-', 'Charpy impact toughness / J'] = df.loc[df['Common_Prefix'] == 'Blond&-1984-', 'Charpy impact toughness / J'].fillna(bld_charpyJ)
df.loc[df['Common_Prefix'] == 'Blond&-1984-', 'Charpy temperature / deg C'] = df.loc[df['Common_Prefix'] == 'Blond&-1984-', 'Charpy temperature / deg C'].fillna(bld_charpyC)

# %%
df[df['Common_Prefix']=='Mart-']['Charpy impact toughness / J'].mean()
# Out:
# 66.66666666666667

# %%
mrt_charpyJ=df[df['Common_Prefix']=='Mart-']['Charpy impact toughness / J'].mean()
mrt_charpyC=df[df['Common_Prefix']=='Mart-']['Charpy temperature / deg C'].mean()

# %%
df.loc[df['Common_Prefix'] == 'Mart-', 'Charpy impact toughness / J'] = df.loc[df['Common_Prefix'] == 'Mart-', 'Charpy impact toughness / J'].fillna(mrt_charpyJ)
df.loc[df['Common_Prefix'] == 'Mart-', 'Charpy temperature / deg C'] = df.loc[df['Common_Prefix'] == 'Mart-', 'Charpy temperature / deg C'].fillna(mrt_charpyC)

# %%
df[df['Common_Prefix']=='Ditt-']['Charpy impact toughness / J'].mean()
# Out:
# 190.33333333333334

# %%
ditt_charpyJ=df[df['Common_Prefix']=='Ditt-']['Charpy impact toughness / J'].mean()
ditt_charpyC=df[df['Common_Prefix']=='Ditt-']['Charpy temperature / deg C'].mean()

# %%
df.loc[df['Common_Prefix'] == 'Ditt-', 'Charpy impact toughness / J'] = df.loc[df['Common_Prefix'] == 'Ditt-', 'Charpy impact toughness / J'].fillna(ditt_charpyJ)
df.loc[df['Common_Prefix'] == 'Ditt-', 'Charpy temperature / deg C'] = df.loc[df['Common_Prefix'] == 'Ditt-', 'Charpy temperature / deg C'].fillna(ditt_charpyC)

# %%
df[df['Common_Prefix']=='Chandel&-1985W']['Charpy impact toughness / J'].mean()
# Out:
# 115.84210526315789

# %%
chdl_charpyJ=df[df['Common_Prefix']=='Chandel&-1985W']['Charpy impact toughness / J'].mean()
chdl_charpyC=df[df['Common_Prefix']=='Chandel&-1985W']['Charpy temperature / deg C'].mean()

# %%
df.loc[df['Common_Prefix'] == 'Chandel&-1985W', 'Charpy impact toughness / J'] = df.loc[df['Common_Prefix'] == 'Chandel&-1985W', 'Charpy impact toughness / J'].fillna(chdl_charpyJ)
df.loc[df['Common_Prefix'] == 'Chandel&-1985W', 'Charpy temperature / deg C'] = df.loc[df['Common_Prefix'] == 'Chandel&-1985W', 'Charpy temperature / deg C'].fillna(chdl_charpyC)

# %%
df['Charpy impact toughness / J'] = df['Charpy impact toughness / J'].fillna(df['Charpy impact toughness / J'].mean())
df['Charpy temperature / deg C'] = df['Charpy temperature / deg C'].fillna(df['Charpy temperature / deg C'].mean())

# %% [markdown]
# ### III. Missing Values: features to delete ###

# %%
#50 % FATT                                                1621
#Primary ferrite in microstructure / %                    1554
#Ferrite with second phase / %                            1562
#Acicular ferrite / %                                     1562
#Martensite / %                                           1563
#Ferrite with carbide aggregate / %                       1563
# Hardness

# %%
df = df.drop(columns=['50 % FATT', 'Primary ferrite in microstructure / %', 'Ferrite with second phase / %', 'Acicular ferrite / %','Martensite / %','Ferrite with carbide aggregate / %'])

# %%
df
# Out:
#       Carbon concentration / (weight%)  Silicon concentration / (weight%)  \
# 0                                0.037                               0.30
# 1                                0.037                               0.30
# 2                                0.037                               0.30
# 3                                0.037                               0.31
# 4                                0.037                               0.31
# ...                                ...                                ...
# 1647                             0.100                               0.35
# 1648                             0.088                               0.36
# 1649                             0.090                               0.34
# 1650                             0.092                               0.35
# 1651                             0.180                               0.39
#
#       Manganese concentration / (weight%)  Sulphur concentration / (weight%)  \
# 0                                    0.65                              0.008
# 1                                    0.65                              0.008
# 2                                    0.65                              0.008
# 3                                    1.03                              0.007
# 4                                    1.03                              0.007
# ...                                   ...                                ...
# 1647                                 0.90                              0.008
# 1648                                 0.88                              0.008
# 1649                                 0.89                              0.008
# 1650                                 0.90                              0.008
# 1651                                 0.88                              0.008
#
#       Phosphorus concentration / (weight%)  Nickel concentration / (weight%)  \
# 0                                    0.012                              0.00
# 1                                    0.012                              0.00
# 2                                    0.012                              0.00
# 3                                    0.014                              0.00
# 4                                    0.014                              0.00
# ...                                    ...                               ...
# 1647                                 0.016                              0.60
# 1648                                 0.017                              0.57
# 1649                                 0.016                              0.17
# 1650                                 0.016                              0.54
# 1651                                 0.017                              0.18
#
#       Chromium concentration / (weight%)  \
# 0                               2.101273
# 1                               2.101273
# 2                               2.101273
# 3                               2.101273
# 4                               2.101273
# ...                                  ...
# 1647                            8.600000
# 1648                            8.400000
# 1649                            8.200000
# 1650                            8.400000
# 1651                           10.200000
#
#       Molybdenum concentration / (weight%)  \
# 0                                 0.479172
# 1                                 0.479172
# 2                                 0.479172
# 3                                 0.479172
# 4                                 0.479172
# ...                                    ...
# 1647                              0.980000
# 1648                              0.940000
# 1649                              0.940000
# 1650                              0.970000
# 1651                              0.940000
#
#       Vanadium concentration / (weight%)  Copper concentration / (weight%)  \
# 0                               0.097379                          0.172163
# 1                               0.097379                          0.172163
# 2                               0.097379                          0.172163
# 3                               0.097379                          0.172163
# 4                               0.097379                          0.172163
# ...                                  ...                               ...
# 1647                            0.180000                          0.172163
# 1648                            0.190000                          0.172163
# 1649                            0.020000                          0.172163
# 1650                            0.170000                          0.172163
# 1651                            0.280000                          0.172163
#
#       ...  Post weld heat treatment time / hours  Yield strength / MPa  \
# 0     ...                                   14.0                 392.0
# 1     ...                                    0.0                   NaN
# 2     ...                                    2.0                 370.0
# 3     ...                                   14.0                 413.0
# 4     ...                                    0.0                   NaN
# ...   ...                                    ...                   ...
# 1647  ...                                    2.0                 834.0
# 1648  ...                                    2.0                 822.0
# 1649  ...                                    2.0                 660.0
# 1650  ...                                    2.0                 832.0
# 1651  ...                                    2.0                   NaN
#
#       Ultimate tensile strength / MPa  Elongation / %  Reduction of Area / %  \
# 0                               466.0            31.9                   80.6
# 1                                 NaN             NaN                    NaN
# 2                               456.0            35.2                   80.6
# 3                               498.0            31.2                   80.6
# 4                                 NaN             NaN                    NaN
# ...                               ...             ...                    ...
# 1647                              NaN             NaN                    NaN
# 1648                              NaN             NaN                    NaN
# 1649                              NaN             NaN                    NaN
# 1650                              NaN             NaN                    NaN
# 1651                              NaN             NaN                    NaN
#
#       Charpy temperature / deg C  Charpy impact toughness / J  \
# 0                     -45.136784                    85.733826
# 1                     -28.000000                   100.000000
# 2                     -38.000000                   100.000000
# 3                     -45.136784                    85.733826
# 4                     -48.000000                   100.000000
# ...                          ...                          ...
# 1647                  -35.008558                    85.892497
# 1648                  -35.008558                    85.892497
# 1649                  -35.008558                    85.892497
# 1650                  -35.008558                    85.892497
# 1651                  -35.008558                    85.892497
#
#       Hardness / kg/mm2                        Weld ID    Common_Prefix
# 0                   NaN    Evans-Ni/CMn-1990/1991-0Aaw            Evans
# 1                   NaN  Evans-Ni/CMn-1990/1991-0Aawch            Evans
# 2                   NaN    Evans-Ni/CMn-1990/1991-0Aht            Evans
# 3                   NaN    Evans-Ni/CMn-1990/1991-0Baw            Evans
# 4                   NaN  Evans-Ni/CMn-1990/1991-0Bawch            Evans
# ...                 ...                            ...              ...
# 1647                NaN               Birmingham-MAX35  Birmingham-MAX3
# 1648                NaN               Birmingham-MAX36  Birmingham-MAX3
# 1649                NaN               Birmingham-MAX37  Birmingham-MAX3
# 1650                NaN               Birmingham-MAX38  Birmingham-MAX3
# 1651                NaN               Birmingham-MAX39  Birmingham-MAX3
#
# [1652 rows x 39 columns]

# %% [markdown]
# ### III.Missing values: Résumé ###

# %%
df.isnull().sum()
# Out:
# Carbon concentration / (weight%)                            0
# Silicon concentration / (weight%)                           0
# Manganese concentration / (weight%)                         0
# Sulphur concentration / (weight%)                           0
# Phosphorus concentration / (weight%)                        0
# Nickel concentration / (weight%)                            0
# Chromium concentration / (weight%)                          0
# Molybdenum concentration / (weight%)                        0
# Vanadium concentration / (weight%)                          0
# Copper concentration / (weight%)                            0
# Cobalt concentration / (weight%)                            0
# Tungsten concentration / (weight%)                          0
# Oxygen concentration / parts per million by weight          0
# Titanium concentration / parts per million by weight        0
# Nitrogen concentration / parts per million by weight        0
# Aluminium concentration / parts per million by weight       0
# Boron concentration / parts per million by weight           0
# Niobium concentration / parts per million by weight         0
# Tin concentration / parts per million by weight             0
# Arsenic concentration / parts per million by weight         0
# Antimony concentration / parts per million by weight        0
# Current / A                                                 0
# Voltage / V                                                 0
# AC or DC                                                    0
# Electrode positive or negative                              0
# Heat input / kJ/mm                                          0
# Interpass temperature / deg C                               0
# Type of weld                                                0
# Post weld heat treatment temperature / deg C                0
# Post weld heat treatment time / hours                       0
# Yield strength / MPa                                      872
# Ultimate tensile strength / MPa                           914
# Elongation / %                                            952
# Reduction of Area / %                                     947
# Charpy temperature / deg C                                  0
# Charpy impact toughness / J                                 0
# Hardness / kg/mm2                                        1514
# Weld ID                                                     0
# Common_Prefix                                               0
# dtype: int64

# %% [markdown]
# # Les variables cibles :
#
# - **Yield strength** / MPa
# - **Ultimate tensile strength** / MPa
# - **Elongation** / %
# - **Reduction of Area** / %

# %% [markdown]
# ## IV. Variables Catégoriques ##

# %% [markdown]
# ### IV. Variables Catégoriques : Introduction

# %%
df.columns
# Out:
# Index(['Carbon concentration / (weight%)', 'Silicon concentration / (weight%)',
#        'Manganese concentration / (weight%)',
#        'Sulphur concentration / (weight%)',
#        'Phosphorus concentration / (weight%)',
#        'Nickel concentration / (weight%)',
#        'Chromium concentration / (weight%)',
#        'Molybdenum concentration / (weight%)',
#        'Vanadium concentration / (weight%)',
#        'Copper concentration / (weight%)', 'Cobalt concentration / (weight%)',
#        'Tungsten concentration / (weight%)',
#        'Oxygen concentration / parts per million by weight',
#        'Titanium concentration / parts per million by weight',
#        'Nitrogen concentration / parts per million by weight',
#        'Aluminium concentration / parts per million by weight',
#        'Boron concentration / parts per million by weight',
#        'Niobium concentration / parts per million by weight',
#        'Tin concentration / parts per million by weight',
#        'Arsenic concentration / parts per million by weight',
#        'Antimony concentration / parts per million by weight', 'Current / A',
#        'Voltage / V', 'AC or DC', 'Electrode positive or negative',
#        'Heat input / kJ/mm', 'Interpass temperature / deg C', 'Type of weld',
#        'Post weld heat treatment temperature / deg C',
#        'Post weld heat treatment time / hours', 'Yield strength / MPa',
#        'Ultimate tensile strength / MPa', 'Elongation / %',
#        'Reduction of Area / %', 'Charpy temperature / deg C',
#        'Charpy impact toughness / J', 'Hardness / kg/mm2', 'Weld ID',
#        'Common_Prefix'],
#       dtype='object')

# %%
#  'AC or DC'
# 'Electrode positive or negative'
# 'Type of weld'
# Sont des variables catégoriques

# %% [markdown]
# ### IV. Variables Catégoriques : AC or DC

# %%
df['AC or DC'].value_counts()
# Out:
# AC or DC
# DC    1551
# o       59
# AC      42
# Name: count, dtype: int64

# %%
df_encoded_1 = pd.get_dummies(df, columns=['AC or DC'])

# %%
df_encoded_1.columns
# Out:
# Index(['Carbon concentration / (weight%)', 'Silicon concentration / (weight%)',
#        'Manganese concentration / (weight%)',
#        'Sulphur concentration / (weight%)',
#        'Phosphorus concentration / (weight%)',
#        'Nickel concentration / (weight%)',
#        'Chromium concentration / (weight%)',
#        'Molybdenum concentration / (weight%)',
#        'Vanadium concentration / (weight%)',
#        'Copper concentration / (weight%)', 'Cobalt concentration / (weight%)',
#        'Tungsten concentration / (weight%)',
#        'Oxygen concentration / parts per million by weight',
#        'Titanium concentration / parts per million by weight',
#        'Nitrogen concentration / parts per million by weight',
#        'Aluminium concentration / parts per million by weight',
#        'Boron concentration / parts per million by weight',
#        'Niobium concentration / parts per million by weight',
#        'Tin concentration / parts per million by weight',
#        'Arsenic concentration / parts per million by weight',
#        'Antimony concentration / parts per million by weight', 'Current / A',
#        'Voltage / V', 'Electrode positive or negative', 'Heat input / kJ/mm',
#        'Interpass temperature / deg C', 'Type of weld',
#        'Post weld heat treatment temperature / deg C',
#        'Post weld heat treatment time / hours', 'Yield strength / MPa',
#        'Ultimate tensile strength / MPa', 'Elongation / %',
#        'Reduction of Area / %', 'Charpy temperature / deg C',
#        'Charpy impact toughness / J', 'Hardness / kg/mm2', 'Weld ID',
#        'Common_Prefix', 'AC or DC_AC', 'AC or DC_DC', 'AC or DC_o'],
#       dtype='object')

# %%
df_encoded_1.drop(columns=['AC or DC_o'],inplace=True)

# %% [markdown]
# ### IV. Variables Catégoriques : 'Electrode positive or negative'

# %%
df['Electrode positive or negative'].value_counts()
# Out:
# Electrode positive or negative
# +    1607
# 0      38
# -       7
# Name: count, dtype: int64

# %%
df_encoded_2 = pd.get_dummies(df_encoded_1, columns=['Electrode positive or negative'])

# %%
df_encoded_2.columns
# Out:
# Index(['Carbon concentration / (weight%)', 'Silicon concentration / (weight%)',
#        'Manganese concentration / (weight%)',
#        'Sulphur concentration / (weight%)',
#        'Phosphorus concentration / (weight%)',
#        'Nickel concentration / (weight%)',
#        'Chromium concentration / (weight%)',
#        'Molybdenum concentration / (weight%)',
#        'Vanadium concentration / (weight%)',
#        'Copper concentration / (weight%)', 'Cobalt concentration / (weight%)',
#        'Tungsten concentration / (weight%)',
#        'Oxygen concentration / parts per million by weight',
#        'Titanium concentration / parts per million by weight',
#        'Nitrogen concentration / parts per million by weight',
#        'Aluminium concentration / parts per million by weight',
#        'Boron concentration / parts per million by weight',
#        'Niobium concentration / parts per million by weight',
#        'Tin concentration / parts per million by weight',
#        'Arsenic concentration / parts per million by weight',
#        'Antimony concentration / parts per million by weight', 'Current / A',
#        'Voltage / V', 'Heat input / kJ/mm', 'Interpass temperature / deg C',
#        'Type of weld', 'Post weld heat treatment temperature / deg C',
#        'Post weld heat treatment time / hours', 'Yield strength / MPa',
#        'Ultimate tensile strength / MPa', 'Elongation / %',
#        'Reduction of Area / %', 'Charpy temperature / deg C',
#        'Charpy impact toughness / J', 'Hardness / kg/mm2', 'Weld ID',
#        'Common_Prefix', 'AC or DC_AC', 'AC or DC_DC',
#        'Electrode positive or negative_+', 'Electrode positive or negative_-',
#        'Electrode positive or negative_0'],
#       dtype='object')

# %%
df_encoded_2.drop(columns=['Electrode positive or negative_-'],inplace=True)

# %% [markdown]
# ### IV. Variables Catégoriques : 'Type of Weld'

# %%
df['Type of weld'].value_counts()
# Out:
# Type of weld
# MMA      1140
# SA        261
# FCA        87
# TSA        87
# ShMA       40
# NGSAW      18
# NGGMA       7
# SAA         4
# GTAA        4
# GMAA        4
# Name: count, dtype: int64

# %%
df_encoded = pd.get_dummies(df_encoded_2, columns=['Type of weld'])

# %%
df_encoded.columns
# Out:
# Index(['Carbon concentration / (weight%)', 'Silicon concentration / (weight%)',
#        'Manganese concentration / (weight%)',
#        'Sulphur concentration / (weight%)',
#        'Phosphorus concentration / (weight%)',
#        'Nickel concentration / (weight%)',
#        'Chromium concentration / (weight%)',
#        'Molybdenum concentration / (weight%)',
#        'Vanadium concentration / (weight%)',
#        'Copper concentration / (weight%)', 'Cobalt concentration / (weight%)',
#        'Tungsten concentration / (weight%)',
#        'Oxygen concentration / parts per million by weight',
#        'Titanium concentration / parts per million by weight',
#        'Nitrogen concentration / parts per million by weight',
#        'Aluminium concentration / parts per million by weight',
#        'Boron concentration / parts per million by weight',
#        'Niobium concentration / parts per million by weight',
#        'Tin concentration / parts per million by weight',
#        'Arsenic concentration / parts per million by weight',
#        'Antimony concentration / parts per million by weight', 'Current / A',
#        'Voltage / V', 'Heat input / kJ/mm', 'Interpass temperature / deg C',
#        'Post weld heat treatment temperature / deg C',
#        'Post weld heat treatment time / hours', 'Yield strength / MPa',
#        'Ultimate tensile strength / MPa', 'Elongation / %',
#        'Reduction of Area / %', 'Charpy temperature / deg C',
#        'Charpy impact toughness / J', 'Hardness / kg/mm2', 'Weld ID',
#        'Common_Prefix', 'AC or DC_AC', 'AC or DC_DC',
#        'Electrode positive or negative_+', 'Electrode positive or negative_0',
#        'Type of weld_FCA', 'Type of weld_GMAA', 'Type of weld_GTAA',
#        'Type of weld_MMA', 'Type of weld_NGGMA', 'Type of weld_NGSAW',
#        'Type of weld_SA', 'Type of weld_SAA', 'Type of weld_ShMA',
#        'Type of weld_TSA'],
#       dtype='object')

# %%
df_encoded.drop(columns=['Type of weld_GMAA'],inplace=True)

# %% [markdown]
# ## V. Analyse des composantes principales: ACP

# %% [markdown]
# ### V. ACP : drop les variables cibles

# %%
df_encoded.columns
# Out:
# Index(['Carbon concentration / (weight%)', 'Silicon concentration / (weight%)',
#        'Manganese concentration / (weight%)',
#        'Sulphur concentration / (weight%)',
#        'Phosphorus concentration / (weight%)',
#        'Nickel concentration / (weight%)',
#        'Chromium concentration / (weight%)',
#        'Molybdenum concentration / (weight%)',
#        'Vanadium concentration / (weight%)',
#        'Copper concentration / (weight%)', 'Cobalt concentration / (weight%)',
#        'Tungsten concentration / (weight%)',
#        'Oxygen concentration / parts per million by weight',
#        'Titanium concentration / parts per million by weight',
#        'Nitrogen concentration / parts per million by weight',
#        'Aluminium concentration / parts per million by weight',
#        'Boron concentration / parts per million by weight',
#        'Niobium concentration / parts per million by weight',
#        'Tin concentration / parts per million by weight',
#        'Arsenic concentration / parts per million by weight',
#        'Antimony concentration / parts per million by weight', 'Current / A',
#        'Voltage / V', 'Heat input / kJ/mm', 'Interpass temperature / deg C',
#        'Post weld heat treatment temperature / deg C',
#        'Post weld heat treatment time / hours', 'Yield strength / MPa',
#        'Ultimate tensile strength / MPa', 'Elongation / %',
#        'Reduction of Area / %', 'Charpy temperature / deg C',
#        'Charpy impact toughness / J', 'Hardness / kg/mm2', 'Weld ID',
#        'Common_Prefix', 'AC or DC_AC', 'AC or DC_DC',
#        'Electrode positive or negative_+', 'Electrode positive or negative_0',
#        'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
#        'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
#        'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA'],
#       dtype='object')

# %%
X=df_encoded[['Carbon concentration / (weight%)', 'Silicon concentration / (weight%)',
       'Manganese concentration / (weight%)',
       'Sulphur concentration / (weight%)',
       'Phosphorus concentration / (weight%)',
       'Nickel concentration / (weight%)',
       'Chromium concentration / (weight%)',
       'Molybdenum concentration / (weight%)',
       'Vanadium concentration / (weight%)',
       'Copper concentration / (weight%)', 'Cobalt concentration / (weight%)',
       'Tungsten concentration / (weight%)',
       'Oxygen concentration / parts per million by weight',
       'Titanium concentration / parts per million by weight',
       'Nitrogen concentration / parts per million by weight',
       'Aluminium concentration / parts per million by weight',
       'Boron concentration / parts per million by weight',
       'Niobium concentration / parts per million by weight',
       'Tin concentration / parts per million by weight',
       'Arsenic concentration / parts per million by weight',
       'Antimony concentration / parts per million by weight', 'Current / A',
       'Voltage / V', 'Heat input / kJ/mm', 'Interpass temperature / deg C',
       'Post weld heat treatment temperature / deg C',
       'Post weld heat treatment time / hours' , 'Charpy temperature / deg C',
       'Charpy impact toughness / J',
        'AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA']]

# %%
y=df_encoded[['Yield strength / MPa',
       'Ultimate tensile strength / MPa', 'Elongation / %',
       'Reduction of Area / %']]

# %%
X.describe()
# Out:
#        Carbon concentration / (weight%)  Silicon concentration / (weight%)  \
# count                       1652.000000                        1652.000000
# mean                           0.075521                           0.328577
# std                            0.023898                           0.112455
# min                            0.029000                           0.040000
# 25%                            0.061750                           0.270000
# 50%                            0.074000                           0.320000
# 75%                            0.086000                           0.360000
# max                            0.180000                           1.140000
#
#        Manganese concentration / (weight%)  Sulphur concentration / (weight%)  \
# count                          1652.000000                        1652.000000
# mean                              1.202821                           0.009529
# std                               0.382137                           0.011213
# min                               0.270000                           0.001000
# 25%                               0.940000                           0.006000
# 50%                               1.270000                           0.007000
# 75%                               1.440000                           0.010000
# max                               2.250000                           0.140000
#
#        Phosphorus concentration / (weight%)  Nickel concentration / (weight%)  \
# count                           1652.000000                       1652.000000
# mean                               0.012981                          0.415034
# std                                0.019573                          0.510950
# min                                0.002000                          0.000000
# 25%                                0.007000                          0.147500
# 50%                                0.010000                          0.415034
# 75%                                0.014000                          0.415034
# max                                0.250000                          3.500000
#
#        Chromium concentration / (weight%)  \
# count                         1652.000000
# mean                             2.101273
# std                              2.084274
# min                              0.000000
# 25%                              1.037500
# 50%                              2.101273
# 75%                              2.101273
# max                             10.200000
#
#        Molybdenum concentration / (weight%)  \
# count                           1652.000000
# mean                               0.479172
# std                                0.330655
# min                                0.000000
# 25%                                0.385000
# 50%                                0.479172
# 75%                                0.479172
# max                                1.500000
#
#        Vanadium concentration / (weight%)  Copper concentration / (weight%)  \
# count                         1652.000000                       1652.000000
# mean                             0.097379                          0.172163
# std                              0.369331                          0.190909
# min                              0.000000                          0.000000
# 25%                              0.002750                          0.140000
# 50%                              0.097379                          0.172163
# 75%                              0.097379                          0.172163
# max                              5.000000                          1.630000
#
#        ...  Tin concentration / parts per million by weight  \
# count  ...                                      1652.000000
# mean   ...                                        42.170986
# std    ...                                        37.652480
# min    ...                                         0.000000
# 25%    ...                                        42.170986
# 50%    ...                                        42.170986
# 75%    ...                                        42.170986
# max    ...                                      1000.000000
#
#        Arsenic concentration / parts per million by weight  \
# count                                        1652.000000
# mean                                           31.044726
# std                                            16.154869
# min                                             0.003000
# 25%                                            31.044726
# 50%                                            31.044726
# 75%                                            31.044726
# max                                           200.000000
#
#        Antimony concentration / parts per million by weight  Current / A  \
# count                                        1652.000000     1652.000000
# mean                                           29.456077      272.540723
# std                                            14.568709      180.544551
# min                                             0.000000      115.000000
# 25%                                            29.456077      170.000000
# 50%                                            29.456077      170.814286
# 75%                                            29.456077      290.000000
# max                                           200.000000      900.000000
#
#        Voltage / V  Heat input / kJ/mm  \
# count  1652.000000         1652.000000
# mean     27.052498            1.700987
# std      11.686836            1.298465
# min      11.500000            0.600000
# 25%      21.000000            1.000000
# 50%      22.058571            1.000000
# 75%      29.000000            2.000000
# max      75.360000            7.900000
#
#        Post weld heat treatment temperature / deg C  \
# count                                   1652.000000
# mean                                     304.253097
# std                                      284.411103
# min                                        0.000000
# 25%                                        0.000000
# 50%                                      250.000000
# 75%                                      580.000000
# max                                      760.000000
#
#        Post weld heat treatment time / hours  Charpy temperature / deg C  \
# count                            1652.000000                 1652.000000
# mean                                5.012386                  -35.008558
# std                                 6.086396                   27.075884
# min                                 0.000000                 -114.000000
# 25%                                 0.000000                  -45.136784
# 50%                                 2.000000                  -37.000000
# 75%                                10.000000                  -30.000000
# max                                24.000000                  188.000000
#
#        Charpy impact toughness / J
# count                  1652.000000
# mean                     85.892497
# std                      38.281865
# min                       3.000000
# 25%                      80.000000
# 50%                      85.892497
# 75%                     100.000000
# max                     270.000000
#
# [8 rows x 28 columns]

# %% [markdown]
# ### V. ACP : Centrer et réduire

# %%
def replace_range_with_avg(value):
    if isinstance(value, str) and '-' in value:
        try:
            # Séparer les deux nombres et calculer la moyenne
            numbers = list(map(float, value.split('-')))
            return sum(numbers) / len(numbers)
        except ValueError:
            return value  # Si ce n'est pas un format attendu, garder la valeur originale
    else:
        return value  # Si ce n'est pas une chaîne au format '150-200', garder la valeur originale

# Appliquer la fonction sur toutes les colonnes du DataFrame
X = X.applymap(replace_range_with_avg)
# Out:
# C:\Users\DF6610\AppData\Local\Temp\ipykernel_6980\92468369.py:13: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   X = X.applymap(replace_range_with_avg)

# %%
def center_and_normalize(df):
    # Initialiser le StandardScaler
    scaler = StandardScaler()
    
    # Appliquer le scaler sur le DataFrame (centrement et normalisation)
    df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
    
    return df_scaled

# %%
X28_scaled = center_and_normalize(X[['Carbon concentration / (weight%)', 'Silicon concentration / (weight%)',
       'Manganese concentration / (weight%)',
       'Sulphur concentration / (weight%)',
       'Phosphorus concentration / (weight%)',
       'Nickel concentration / (weight%)',
       'Chromium concentration / (weight%)',
       'Molybdenum concentration / (weight%)',
       'Vanadium concentration / (weight%)',
       'Copper concentration / (weight%)', 'Cobalt concentration / (weight%)',
       'Tungsten concentration / (weight%)',
       'Oxygen concentration / parts per million by weight',
       'Titanium concentration / parts per million by weight',
       'Nitrogen concentration / parts per million by weight',
       'Aluminium concentration / parts per million by weight',
       'Boron concentration / parts per million by weight',
       'Niobium concentration / parts per million by weight',
       'Tin concentration / parts per million by weight',
       'Arsenic concentration / parts per million by weight',
       'Antimony concentration / parts per million by weight', 'Current / A',
       'Voltage / V', 'Heat input / kJ/mm', 'Interpass temperature / deg C',
       'Post weld heat treatment temperature / deg C',
       'Post weld heat treatment time / hours' , 'Charpy temperature / deg C',
       'Charpy impact toughness / J']])

# %%
X28_scaled
# Out:
#       Carbon concentration / (weight%)  Silicon concentration / (weight%)  \
# 0                            -1.612394                          -0.254200
# 1                            -1.612394                          -0.254200
# 2                            -1.612394                          -0.254200
# 3                            -1.612394                          -0.165249
# 4                            -1.612394                          -0.165249
# ...                                ...                                ...
# 1647                          1.024597                           0.190556
# 1648                          0.522313                           0.279507
# 1649                          0.606027                           0.101605
# 1650                          0.689741                           0.190556
# 1651                          4.373157                           0.546361
#
#       Manganese concentration / (weight%)  Sulphur concentration / (weight%)  \
# 0                               -1.447095                          -0.136415
# 1                               -1.447095                          -0.136415
# 2                               -1.447095                          -0.136415
# 3                               -0.452386                          -0.225627
# 4                               -0.452386                          -0.225627
# ...                                   ...                                ...
# 1647                            -0.792681                          -0.136415
# 1648                            -0.845034                          -0.136415
# 1649                            -0.818857                          -0.136415
# 1650                            -0.792681                          -0.136415
# 1651                            -0.845034                          -0.136415
#
#       Phosphorus concentration / (weight%)  Nickel concentration / (weight%)  \
# 0                                -0.050153                         -0.812525
# 1                                -0.050153                         -0.812525
# 2                                -0.050153                         -0.812525
# 3                                 0.052059                         -0.812525
# 4                                 0.052059                         -0.812525
# ...                                    ...                               ...
# 1647                              0.154270                          0.362113
# 1648                              0.205376                          0.303381
# 1649                              0.154270                         -0.479711
# 1650                              0.154270                          0.244649
# 1651                              0.205376                         -0.460134
#
#       Chromium concentration / (weight%)  \
# 0                          -2.131311e-16
# 1                          -2.131311e-16
# 2                          -2.131311e-16
# 3                          -2.131311e-16
# 4                          -2.131311e-16
# ...                                  ...
# 1647                        3.118925e+00
# 1648                        3.022939e+00
# 1649                        2.926953e+00
# 1650                        3.022939e+00
# 1651                        3.886810e+00
#
#       Molybdenum concentration / (weight%)  \
# 0                             1.343467e-15
# 1                             1.343467e-15
# 2                             1.343467e-15
# 3                             1.343467e-15
# 4                             1.343467e-15
# ...                                    ...
# 1647                          1.515115e+00
# 1648                          1.394107e+00
# 1649                          1.394107e+00
# 1650                          1.484863e+00
# 1651                          1.394107e+00
#
#       Vanadium concentration / (weight%)  Copper concentration / (weight%)  \
# 0                           7.893242e-16                     -2.908609e-16
# 1                           7.893242e-16                     -2.908609e-16
# 2                           7.893242e-16                     -2.908609e-16
# 3                           7.893242e-16                     -2.908609e-16
# 4                           7.893242e-16                     -2.908609e-16
# ...                                  ...                               ...
# 1647                        2.237726e-01                     -2.908609e-16
# 1648                        2.508568e-01                     -2.908609e-16
# 1649                       -2.095744e-01                     -2.908609e-16
# 1650                        1.966884e-01                     -2.908609e-16
# 1651                        4.946145e-01                     -2.908609e-16
#
#       ...  Arsenic concentration / parts per million by weight  \
# 0     ...                                      -4.399651e-16
# 1     ...                                      -4.399651e-16
# 2     ...                                      -4.399651e-16
# 3     ...                                      -4.399651e-16
# 4     ...                                      -4.399651e-16
# ...   ...                                                ...
# 1647  ...                                      -4.399651e-16
# 1648  ...                                      -4.399651e-16
# 1649  ...                                      -4.399651e-16
# 1650  ...                                      -4.399651e-16
# 1651  ...                                      -4.399651e-16
#
#       Antimony concentration / parts per million by weight  Current / A  \
# 0                                                   0.0       -0.568124
# 1                                                   0.0       -0.568124
# 2                                                   0.0       -0.568124
# 3                                                   0.0       -0.568124
# 4                                                   0.0       -0.568124
# ...                                                 ...             ...
# 1647                                                0.0        0.983209
# 1648                                                0.0        0.983209
# 1649                                                0.0        0.983209
# 1650                                                0.0        0.983209
# 1651                                                0.0        0.983209
#
#       Voltage / V  Heat input / kJ/mm  Interpass temperature / deg C  \
# 0       -0.518047           -0.540021                      -0.107148
# 1       -0.518047           -0.540021                      -0.107148
# 2       -0.518047           -0.540021                      -0.107148
# 3       -0.518047           -0.540021                      -0.107148
# 4       -0.518047           -0.540021                      -0.107148
# ...           ...                 ...                            ...
# 1647     0.252283            0.230352                      -0.107148
# 1648     0.252283            0.230352                      -0.107148
# 1649     0.252283            0.230352                      -0.107148
# 1650     0.252283            0.230352                      -0.107148
# 1651     0.252283            0.230352                      -0.107148
#
#       Post weld heat treatment temperature / deg C  \
# 0                                        -0.190814
# 1                                        -1.070089
# 2                                         0.969830
# 3                                        -0.190814
# 4                                        -1.070089
# ...                                            ...
# 1647                                      1.602908
# 1648                                      1.602908
# 1649                                      1.602908
# 1650                                      1.602908
# 1651                                      1.602908
#
#       Post weld heat treatment time / hours  Charpy temperature / deg C  \
# 0                                  1.477120                   -0.374181
# 1                                 -0.823789                    0.258927
# 2                                 -0.495087                   -0.110517
# 3                                  1.477120                   -0.374181
# 4                                 -0.823789                   -0.479961
# ...                                     ...                         ...
# 1647                              -0.495087                    0.000000
# 1648                              -0.495087                    0.000000
# 1649                              -0.495087                    0.000000
# 1650                              -0.495087                    0.000000
# 1651                              -0.495087                    0.000000
#
#       Charpy impact toughness / J
# 0                   -4.146058e-03
# 1                    3.686282e-01
# 2                    3.686282e-01
# 3                   -4.146058e-03
# 4                    3.686282e-01
# ...                           ...
# 1647                -3.713288e-16
# 1648                -3.713288e-16
# 1649                -3.713288e-16
# 1650                -3.713288e-16
# 1651                -3.713288e-16
#
# [1652 rows x 29 columns]

# %% [markdown]
# ### V. ACP : Choix du nombre de composants

# %%
# Appliquer la PCA
pca = PCA()  # Laisser scikit-learn décider du nombre maximal de composantes
pca.fit(X28_scaled)

# Variance expliquée par chaque composante
explained_variance_ratio = pca.explained_variance_ratio_

# Calcul de la variance cumulée
explained_variance_cumulative = np.cumsum(explained_variance_ratio)

# Tracer le graphe
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_variance_cumulative) + 1), explained_variance_cumulative, marker='', linestyle='-')
plt.title('Variance expliquée cumulée en fonction du nombre de composantes principales')
plt.xlabel('Nombre de composantes principales')
plt.ylabel('Variance expliquée cumulée')
# Ajouter une ligne horizontale pour montrer le seuil de 95% de variance expliquée
plt.axhline(y=0.9, color='r', linestyle='--', label='95% de variance expliquée')

# Ajouter des titres et des labels
plt.title('Variance expliquée cumulée en fonction du nombre de composantes principales')
plt.xlabel('Nombre de composantes principales')
plt.ylabel('Variance expliquée cumulée')

# Afficher la grille et la légende
plt.grid(True)
plt.legend(loc='best')
plt.show()

# %%
# si on prend 20 composantes on aura 90% de la variance

# %% [markdown]
# ### V. ACP

# %%
# Appliquer la PCA
pca = PCA(n_components=20) 
pca.fit(X28_scaled)
pca_result = pca.transform(X28_scaled)
# Créer un DataFrame pour les résultats de la PCA
pca_X = pd.DataFrame(pca_result, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', 
  'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18','PC19','PC20'])
# Afficher les résultats
pca_X
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     0.797559 -1.243604 -0.877140 -0.262090  0.049972 -0.101886  0.187807
# 1     0.191637 -0.946577 -0.121267  0.400053 -0.032788  0.490045  0.708667
# 2     0.896423 -0.926910 -0.410839  0.074153 -0.078237  0.399860  0.163795
# 3     0.612019 -1.248647 -0.749723 -0.004150  0.162214 -0.124930  0.151968
# 4    -0.105725 -1.119186 -0.055004  0.583392  0.193385  0.119365  0.516923
# ...        ...       ...       ...       ...       ...       ...       ...
# 1647  3.038229  1.795574  1.509149 -0.212588 -0.042027 -0.115225 -0.869771
# 1648  4.808031  2.670633  3.264781  0.359646  0.028428 -0.362408 -0.098992
# 1649  1.652439  1.172069  0.669415 -0.227183 -0.617368  0.067445 -0.859174
# 1650  2.611957  1.566247  1.652512  0.018777 -0.531194 -0.098718 -0.414819
# 1651  1.751771  2.064667  1.831006 -0.900051 -0.757920  0.407570 -2.497671
#
#            PC8       PC9      PC10      PC11      PC12      PC13      PC14  \
# 0    -0.931963  0.419365  0.621394  0.509015  0.380826  0.333745  0.101285
# 1    -0.569250  0.560366  0.113864  0.138211  0.201124  0.268386 -0.559635
# 2    -0.927108  0.544266  0.112373  0.402958  0.303539  0.176133 -0.083308
# 3    -0.563293  0.345061  0.748242  0.291948  0.057517  0.244182 -0.190327
# 4    -0.068460  0.494983  0.147713  0.028800 -0.008664  0.179886 -0.794430
# ...        ...       ...       ...       ...       ...       ...       ...
# 1647  0.539871 -0.294937 -1.029650  0.344167  0.305348 -0.295061  0.563932
# 1648  0.425616 -0.598172 -1.369174  0.442300  0.208994 -0.010876 -0.644396
# 1649 -0.242586 -0.155671 -0.539170  0.534169 -0.043788 -0.302953  0.823043
# 1650 -0.023989 -0.681137 -0.744184  0.408692  0.295778 -0.133645  0.420452
# 1651  0.868177 -0.924590 -0.606803  1.335984 -0.542200 -0.840921  1.804337
#
#           PC15      PC16      PC17      PC18      PC19      PC20
# 0     0.363268 -0.392848  0.088598 -1.466268  0.205486  0.337017
# 1    -0.637160 -1.482710  0.587462 -1.244049  0.640521  0.303317
# 2    -0.619629 -0.987714  0.537169 -0.638320  0.648522 -0.055854
# 3     0.649637  0.002578  0.041214 -1.044926  0.283594  0.249038
# 4    -0.351143 -1.153179  0.686908 -0.790560  0.832369  0.167688
# ...        ...       ...       ...       ...       ...       ...
# 1647 -0.772949 -0.604753 -0.901064  0.339436  0.073573 -0.512355
# 1648 -0.390194 -0.731076 -1.944285 -0.776175 -0.692140 -0.325335
# 1649 -0.485357 -0.808112 -0.232425  0.558158  0.629427  0.049737
# 1650 -0.557028 -0.663613 -0.940846  0.295216  0.001250  0.086947
# 1651 -0.818127 -0.387648 -0.610830  0.965282 -0.222905  0.110019
#
# [1652 rows x 20 columns]

# %%
print("Variance expliquée cumulée par chaque composante :", pca.explained_variance_ratio_.sum())
# Out:
# Variance expliquée cumulée par chaque composante : 0.9137576997162394

# %%
X_processed=pd.concat([pca_X,X[['AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA']]],axis=1)

# %%
data_processed=pd.concat([X_processed,y],axis=1)
data_processed
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     0.797559 -1.243604 -0.877140 -0.262090  0.049972 -0.101886  0.187807
# 1     0.191637 -0.946577 -0.121267  0.400053 -0.032788  0.490045  0.708667
# 2     0.896423 -0.926910 -0.410839  0.074153 -0.078237  0.399860  0.163795
# 3     0.612019 -1.248647 -0.749723 -0.004150  0.162214 -0.124930  0.151968
# 4    -0.105725 -1.119186 -0.055004  0.583392  0.193385  0.119365  0.516923
# ...        ...       ...       ...       ...       ...       ...       ...
# 1647  3.038229  1.795574  1.509149 -0.212588 -0.042027 -0.115225 -0.869771
# 1648  4.808031  2.670633  3.264781  0.359646  0.028428 -0.362408 -0.098992
# 1649  1.652439  1.172069  0.669415 -0.227183 -0.617368  0.067445 -0.859174
# 1650  2.611957  1.566247  1.652512  0.018777 -0.531194 -0.098718 -0.414819
# 1651  1.751771  2.064667  1.831006 -0.900051 -0.757920  0.407570 -2.497671
#
#            PC8       PC9      PC10  ...  Type of weld_NGGMA  \
# 0    -0.931963  0.419365  0.621394  ...               False
# 1    -0.569250  0.560366  0.113864  ...               False
# 2    -0.927108  0.544266  0.112373  ...               False
# 3    -0.563293  0.345061  0.748242  ...               False
# 4    -0.068460  0.494983  0.147713  ...               False
# ...        ...       ...       ...  ...                 ...
# 1647  0.539871 -0.294937 -1.029650  ...               False
# 1648  0.425616 -0.598172 -1.369174  ...               False
# 1649 -0.242586 -0.155671 -0.539170  ...               False
# 1650 -0.023989 -0.681137 -0.744184  ...               False
# 1651  0.868177 -0.924590 -0.606803  ...               False
#
#       Type of weld_NGSAW  Type of weld_SA  Type of weld_SAA  \
# 0                  False            False             False
# 1                  False            False             False
# 2                  False            False             False
# 3                  False            False             False
# 4                  False            False             False
# ...                  ...              ...               ...
# 1647               False             True             False
# 1648               False             True             False
# 1649               False             True             False
# 1650               False             True             False
# 1651               False             True             False
#
#       Type of weld_ShMA  Type of weld_TSA  Yield strength / MPa  \
# 0                 False             False                 392.0
# 1                 False             False                   NaN
# 2                 False             False                 370.0
# 3                 False             False                 413.0
# 4                 False             False                   NaN
# ...                 ...               ...                   ...
# 1647              False             False                 834.0
# 1648              False             False                 822.0
# 1649              False             False                 660.0
# 1650              False             False                 832.0
# 1651              False             False                   NaN
#
#       Ultimate tensile strength / MPa  Elongation / %  Reduction of Area / %
# 0                               466.0            31.9                   80.6
# 1                                 NaN             NaN                    NaN
# 2                               456.0            35.2                   80.6
# 3                               498.0            31.2                   80.6
# 4                                 NaN             NaN                    NaN
# ...                               ...             ...                    ...
# 1647                              NaN             NaN                    NaN
# 1648                              NaN             NaN                    NaN
# 1649                              NaN             NaN                    NaN
# 1650                              NaN             NaN                    NaN
# 1651                              NaN             NaN                    NaN
#
# [1652 rows x 37 columns]

# %% [markdown]
# ### V. ACP : interprétation

# %%
#Projection des données sur les deux premières composantes principales
plt.figure(figsize=(10, 6))
plt.scatter(pca_result[:, 0], pca_result[:, 1], c='blue', edgecolor='k', s=50)
plt.title('Projection des données sur les deux premières composantes principales')
plt.xlabel('Première composante principale')
plt.ylabel('Deuxième composante principale')
plt.grid(True)
plt.show()

# %%
# Contribution des variables aux composantes principales
# Créer un DataFrame pour visualiser les coefficients
components_df = pd.DataFrame(pca.components_, columns=X28_scaled.columns, index=[f'Composante {i+1}' for i in range(pca.n_components_)])

# Afficher les poids des variables pour les deux premières composantes
print("Poids des variables pour les deux premières composantes principales :")
components_df
# Out:
# Poids des variables pour les deux premières composantes principales :
#                Carbon concentration / (weight%)  \
# Composante 1                          -0.046470
# Composante 2                           0.230007
# Composante 3                           0.195987
# Composante 4                          -0.232600
# Composante 5                          -0.060168
# Composante 6                           0.076177
# Composante 7                          -0.378103
# Composante 8                           0.188283
# Composante 9                          -0.091380
# Composante 10                         -0.091098
# Composante 11                          0.192523
# Composante 12                         -0.166209
# Composante 13                         -0.150276
# Composante 14                          0.275813
# Composante 15                         -0.012304
# Composante 16                          0.149485
# Composante 17                         -0.000238
# Composante 18                          0.198198
# Composante 19                         -0.204496
# Composante 20                          0.067527
#
#                Silicon concentration / (weight%)  \
# Composante 1                           -0.144884
# Composante 2                           -0.116466
# Composante 3                            0.109413
# Composante 4                            0.471247
# Composante 5                           -0.052267
# Composante 6                            0.004140
# Composante 7                           -0.253664
# Composante 8                           -0.115886
# Composante 9                            0.100687
# Composante 10                          -0.078817
# Composante 11                           0.069106
# Composante 12                          -0.062720
# Composante 13                           0.041836
# Composante 14                          -0.104132
# Composante 15                          -0.070569
# Composante 16                           0.094940
# Composante 17                          -0.231976
# Composante 18                          -0.233372
# Composante 19                          -0.339508
# Composante 20                          -0.368476
#
#                Manganese concentration / (weight%)  \
# Composante 1                             -0.176327
# Composante 2                              0.003964
# Composante 3                              0.118377
# Composante 4                              0.210862
# Composante 5                              0.106460
# Composante 6                             -0.025760
# Composante 7                             -0.013916
# Composante 8                              0.381350
# Composante 9                             -0.081208
# Composante 10                             0.133395
# Composante 11                            -0.226955
# Composante 12                            -0.318884
# Composante 13                            -0.092025
# Composante 14                            -0.286275
# Composante 15                             0.295412
# Composante 16                             0.383411
# Composante 17                            -0.022750
# Composante 18                             0.448057
# Composante 19                             0.098634
# Composante 20                            -0.057658
#
#                Sulphur concentration / (weight%)  \
# Composante 1                           -0.003606
# Composante 2                            0.304383
# Composante 3                           -0.322562
# Composante 4                            0.192397
# Composante 5                            0.436123
# Composante 6                            0.171183
# Composante 7                           -0.014284
# Composante 8                            0.040477
# Composante 9                            0.002547
# Composante 10                          -0.036954
# Composante 11                           0.091947
# Composante 12                           0.033129
# Composante 13                          -0.002185
# Composante 14                           0.043785
# Composante 15                          -0.049752
# Composante 16                          -0.016103
# Composante 17                           0.072664
# Composante 18                           0.008244
# Composante 19                          -0.093008
# Composante 20                           0.020433
#
#                Phosphorus concentration / (weight%)  \
# Composante 1                               0.023677
# Composante 2                               0.279111
# Composante 3                              -0.282189
# Composante 4                               0.229320
# Composante 5                               0.488221
# Composante 6                               0.171044
# Composante 7                              -0.006921
# Composante 8                               0.031863
# Composante 9                              -0.022060
# Composante 10                             -0.020810
# Composante 11                              0.105102
# Composante 12                              0.023708
# Composante 13                             -0.018991
# Composante 14                              0.061803
# Composante 15                             -0.055191
# Composante 16                              0.040723
# Composante 17                              0.023126
# Composante 18                             -0.027889
# Composante 19                              0.018572
# Composante 20                              0.038870
#
#                Nickel concentration / (weight%)  \
# Composante 1                           0.005283
# Composante 2                          -0.133038
# Composante 3                           0.010845
# Composante 4                           0.034261
# Composante 5                           0.082022
# Composante 6                          -0.101661
# Composante 7                           0.416925
# Composante 8                           0.085782
# Composante 9                          -0.279282
# Composante 10                         -0.344294
# Composante 11                         -0.263797
# Composante 12                          0.431823
# Composante 13                          0.031086
# Composante 14                          0.229070
# Composante 15                         -0.174555
# Composante 16                          0.278978
# Composante 17                         -0.176900
# Composante 18                          0.226552
# Composante 19                         -0.242173
# Composante 20                         -0.073649
#
#                Chromium concentration / (weight%)  \
# Composante 1                             0.378064
# Composante 2                             0.094237
# Composante 3                             0.276485
# Composante 4                             0.062994
# Composante 5                            -0.010285
# Composante 6                            -0.044072
# Composante 7                            -0.017179
# Composante 8                             0.104498
# Composante 9                            -0.056444
# Composante 10                           -0.146817
# Composante 11                           -0.002801
# Composante 12                           -0.014798
# Composante 13                           -0.027392
# Composante 14                           -0.066945
# Composante 15                            0.023105
# Composante 16                           -0.104140
# Composante 17                           -0.092807
# Composante 18                           -0.029736
# Composante 19                            0.017586
# Composante 20                            0.059925
#
#                Molybdenum concentration / (weight%)  \
# Composante 1                               0.389865
# Composante 2                               0.040550
# Composante 3                              -0.000074
# Composante 4                               0.100084
# Composante 5                              -0.112408
# Composante 6                               0.056341
# Composante 7                              -0.088336
# Composante 8                               0.024501
# Composante 9                              -0.053655
# Composante 10                              0.057335
# Composante 11                              0.057638
# Composante 12                              0.089942
# Composante 13                              0.000056
# Composante 14                              0.131799
# Composante 15                             -0.047574
# Composante 16                             -0.176531
# Composante 17                             -0.024583
# Composante 18                              0.318875
# Composante 19                              0.215823
# Composante 20                              0.145901
#
#                Vanadium concentration / (weight%)  \
# Composante 1                             0.057704
# Composante 2                            -0.027244
# Composante 3                             0.015835
# Composante 4                            -0.066111
# Composante 5                             0.068229
# Composante 6                             0.007898
# Composante 7                            -0.222735
# Composante 8                             0.247533
# Composante 9                            -0.304463
# Composante 10                            0.658481
# Composante 11                           -0.100029
# Composante 12                            0.326055
# Composante 13                            0.182943
# Composante 14                           -0.215945
# Composante 15                           -0.316794
# Composante 16                           -0.086175
# Composante 17                           -0.097606
# Composante 18                           -0.013437
# Composante 19                           -0.116765
# Composante 20                           -0.039135
#
#                Copper concentration / (weight%)  ...  \
# Composante 1                          -0.052946  ...
# Composante 2                          -0.014952  ...
# Composante 3                          -0.035603  ...
# Composante 4                          -0.058255  ...
# Composante 5                           0.003042  ...
# Composante 6                          -0.183611  ...
# Composante 7                           0.462481  ...
# Composante 8                          -0.016356  ...
# Composante 9                           0.122312  ...
# Composante 10                          0.190706  ...
# Composante 11                          0.640145  ...
# Composante 12                         -0.179452  ...
# Composante 13                          0.002318  ...
# Composante 14                         -0.161902  ...
# Composante 15                         -0.176714  ...
# Composante 16                         -0.047290  ...
# Composante 17                         -0.253400  ...
# Composante 18                          0.291476  ...
# Composante 19                         -0.167344  ...
# Composante 20                          0.033735  ...
#
#                Arsenic concentration / parts per million by weight  \
# Composante 1                                           -0.111219
# Composante 2                                           -0.031798
# Composante 3                                            0.321109
# Composante 4                                           -0.173531
# Composante 5                                            0.262781
# Composante 6                                           -0.034552
# Composante 7                                           -0.080735
# Composante 8                                           -0.337797
# Composante 9                                            0.027327
# Composante 10                                           0.118489
# Composante 11                                          -0.150882
# Composante 12                                          -0.197079
# Composante 13                                          -0.105909
# Composante 14                                           0.160531
# Composante 15                                          -0.347678
# Composante 16                                          -0.015707
# Composante 17                                           0.168689
# Composante 18                                           0.155220
# Composante 19                                          -0.296103
# Composante 20                                          -0.125054
#
#                Antimony concentration / parts per million by weight  \
# Composante 1                                           -0.171065
# Composante 2                                           -0.053969
# Composante 3                                            0.372170
# Composante 4                                           -0.122835
# Composante 5                                            0.269755
# Composante 6                                            0.184084
# Composante 7                                           -0.006329
# Composante 8                                           -0.074465
# Composante 9                                            0.091394
# Composante 10                                          -0.018338
# Composante 11                                           0.043327
# Composante 12                                           0.173952
# Composante 13                                           0.072919
# Composante 14                                          -0.086532
# Composante 15                                           0.131053
# Composante 16                                           0.083824
# Composante 17                                           0.055971
# Composante 18                                          -0.060348
# Composante 19                                          -0.144001
# Composante 20                                           0.618743
#
#                Current / A  Voltage / V  Heat input / kJ/mm  \
# Composante 1     -0.211125    -0.109014           -0.209414
# Composante 2      0.441162     0.408408            0.435933
# Composante 3     -0.017596    -0.010311           -0.000941
# Composante 4     -0.119530    -0.119852           -0.118732
# Composante 5     -0.186755    -0.071371           -0.106422
# Composante 6     -0.080524    -0.177625           -0.137547
# Composante 7     -0.011806     0.135761            0.041379
# Composante 8     -0.066076    -0.006659           -0.086008
# Composante 9     -0.028928     0.051853           -0.020062
# Composante 10     0.033308    -0.014519            0.050482
# Composante 11    -0.045551    -0.230216           -0.127120
# Composante 12     0.032110     0.074214            0.001917
# Composante 13     0.012875     0.084063            0.035388
# Composante 14     0.074031    -0.109346            0.033875
# Composante 15    -0.027382     0.080388            0.007564
# Composante 16     0.031019    -0.132817           -0.028497
# Composante 17    -0.114253    -0.091039           -0.095508
# Composante 18    -0.050462     0.050976           -0.027614
# Composante 19     0.033909    -0.024617            0.024933
# Composante 20    -0.073192     0.063944           -0.098124
#
#                Interpass temperature / deg C  \
# Composante 1                       -0.191422
# Composante 2                        0.096126
# Composante 3                        0.025845
# Composante 4                       -0.017193
# Composante 5                       -0.254865
# Composante 6                        0.208343
# Composante 7                       -0.202217
# Composante 8                        0.274296
# Composante 9                        0.105979
# Composante 10                      -0.229843
# Composante 11                       0.342140
# Composante 12                       0.408285
# Composante 13                       0.158954
# Composante 14                      -0.114637
# Composante 15                       0.075192
# Composante 16                       0.004446
# Composante 17                       0.083596
# Composante 18                       0.114473
# Composante 19                      -0.209865
# Composante 20                      -0.076037
#
#                Post weld heat treatment temperature / deg C  \
# Composante 1                                       0.345840
# Composante 2                                       0.066408
# Composante 3                                      -0.082320
# Composante 4                                      -0.106018
# Composante 5                                      -0.044656
# Composante 6                                       0.048397
# Composante 7                                      -0.221469
# Composante 8                                      -0.187123
# Composante 9                                      -0.005571
# Composante 10                                     -0.023621
# Composante 11                                      0.092748
# Composante 12                                      0.018084
# Composante 13                                     -0.053036
# Composante 14                                      0.186961
# Composante 15                                     -0.059799
# Composante 16                                      0.187124
# Composante 17                                     -0.020399
# Composante 18                                      0.325356
# Composante 19                                      0.012458
# Composante 20                                     -0.178989
#
#                Post weld heat treatment time / hours  \
# Composante 1                                0.167966
# Composante 2                               -0.097401
# Composante 3                               -0.277057
# Composante 4                               -0.220051
# Composante 5                               -0.034437
# Composante 6                               -0.045917
# Composante 7                               -0.046062
# Composante 8                               -0.128389
# Composante 9                               -0.027979
# Composante 10                               0.283521
# Composante 11                               0.066076
# Composante 12                               0.026663
# Composante 13                               0.046865
# Composante 14                               0.202413
# Composante 15                               0.424985
# Composante 16                               0.444861
# Composante 17                              -0.249758
# Composante 18                              -0.225264
# Composante 19                              -0.225988
# Composante 20                               0.090591
#
#                Charpy temperature / deg C  Charpy impact toughness / J
# Composante 1                     0.151338                    -0.029973
# Composante 2                     0.226781                    -0.032919
# Composante 3                     0.082764                    -0.017145
# Composante 4                     0.100964                    -0.003525
# Composante 5                    -0.154192                    -0.278030
# Composante 6                     0.470486                     0.619585
# Composante 7                     0.211000                     0.232198
# Composante 8                    -0.178810                     0.042852
# Composante 9                    -0.012073                     0.212914
# Composante 10                    0.125863                     0.119025
# Composante 11                   -0.145701                    -0.120646
# Composante 12                   -0.153636                    -0.013904
# Composante 13                   -0.001439                    -0.008715
# Composante 14                   -0.076896                     0.047982
# Composante 15                    0.000477                    -0.202425
# Composante 16                    0.089180                     0.112116
# Composante 17                   -0.198717                     0.086021
# Composante 18                   -0.043507                     0.047027
# Composante 19                   -0.153932                     0.062957
# Composante 20                    0.064489                    -0.062955
#
# [20 rows x 29 columns]

# %%
# Visualiser les poids des variables pour les deux premières composantes
plt.figure(figsize=(10, 6))
plt.barh(components_df.columns, components_df.iloc[0], color='b', alpha=0.7, label='Composante 1')
plt.barh(components_df.columns, components_df.iloc[1], color='g', alpha=0.7, label='Composante 2')
plt.title('Poids des variables pour les deux premières composantes principales')
plt.xlabel('Poids')
plt.ylabel('Variables')
plt.legend()
plt.grid(True)
plt.show()

# %%
# La composante 2 synthétise bien les infos sur les concentrations en Carbone, Sulphur, Phosphore la charpy temperature par exemple.
# La composabte 1 de même pour les concentrations en Manganese, chromium, copper

# %%
scaled_features=X_processed

# %% [markdown]
# ## VII. Regressions

# %%
y.isnull().sum()
# Out:
# Yield strength / MPa               872
# Ultimate tensile strength / MPa    914
# Elongation / %                     952
# Reduction of Area / %              947
# dtype: int64

# %% [markdown]
# ### VII. Yield strength

# %%
data_processed.columns
# Out:
# Index(['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
#        'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
#        'PC20', 'AC or DC_AC', 'AC or DC_DC',
#        'Electrode positive or negative_+', 'Electrode positive or negative_0',
#        'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
#        'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
#        'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA',
#        'Yield strength / MPa', 'Ultimate tensile strength / MPa',
#        'Elongation / %', 'Reduction of Area / %'],
#       dtype='object')

# %%
yield_data=data_processed[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
       'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
       'PC20', 'AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA',
       'Yield strength / MPa']]

# %%
yield_data_test=yield_data[yield_data['Yield strength / MPa'].isnull()]
yield_data_test
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 1     0.191637 -0.946577 -0.121267  0.400053 -0.032788  0.490045  0.708667
# 4    -0.105725 -1.119186 -0.055004  0.583392  0.193385  0.119365  0.516923
# 7    -0.383471 -1.130974  0.150010  0.885047  0.297111  0.029276  0.262337
# 10   -0.467211 -0.942067  0.285916  1.102690  0.385389  0.281618  0.392561
# 15   -0.101108 -1.262912  0.088667  0.609782  0.220693 -0.186012  0.747267
# ...        ...       ...       ...       ...       ...       ...       ...
# 1638 -1.069155 -1.469450 -1.393595 -1.861504  0.335930 -0.499417  1.957167
# 1639 -1.219635 -1.717515 -1.474473 -1.992886  1.069774 -2.308203  1.231895
# 1641 -1.033400 -1.327159 -1.543491 -1.813324  0.142618 -0.455387  3.596232
# 1642 -1.267747 -1.700898 -1.670234 -2.000656  0.961910 -2.524901  2.754031
# 1651  1.751771  2.064667  1.831006 -0.900051 -0.757920  0.407570 -2.497671
#
#            PC8       PC9      PC10  ...  Type of weld_FCA  Type of weld_GTAA  \
# 1    -0.569250  0.560366  0.113864  ...             False              False
# 4    -0.068460  0.494983  0.147713  ...             False              False
# 7     0.377801  0.421233  0.209400  ...             False              False
# 10    0.729727  0.301269  0.433887  ...             False              False
# 15   -0.038613  0.156444 -0.243391  ...             False              False
# ...        ...       ...       ...  ...               ...                ...
# 1638  0.031782  0.965693  1.296542  ...             False              False
# 1639  0.195585  0.581630  0.900566  ...             False              False
# 1641 -0.423468  1.365672  2.015753  ...             False              False
# 1642 -0.160575  0.988300  1.550028  ...             False              False
# 1651  0.868177 -0.924590 -0.606803  ...             False              False
#
#       Type of weld_MMA  Type of weld_NGGMA  Type of weld_NGSAW  \
# 1                 True               False               False
# 4                 True               False               False
# 7                 True               False               False
# 10                True               False               False
# 15                True               False               False
# ...                ...                 ...                 ...
# 1638              True               False               False
# 1639              True               False               False
# 1641              True               False               False
# 1642              True               False               False
# 1651             False               False               False
#
#       Type of weld_SA  Type of weld_SAA  Type of weld_ShMA  Type of weld_TSA  \
# 1               False             False              False             False
# 4               False             False              False             False
# 7               False             False              False             False
# 10              False             False              False             False
# 15              False             False              False             False
# ...               ...               ...                ...               ...
# 1638            False             False              False             False
# 1639            False             False              False             False
# 1641            False             False              False             False
# 1642            False             False              False             False
# 1651             True             False              False             False
#
#       Yield strength / MPa
# 1                      NaN
# 4                      NaN
# 7                      NaN
# 10                     NaN
# 15                     NaN
# ...                    ...
# 1638                   NaN
# 1639                   NaN
# 1641                   NaN
# 1642                   NaN
# 1651                   NaN
#
# [872 rows x 34 columns]

# %%
yield_data_model = yield_data[yield_data['Yield strength / MPa'].notnull()]
yield_data_model.columns
# Out:
# Index(['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
#        'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
#        'PC20', 'AC or DC_AC', 'AC or DC_DC',
#        'Electrode positive or negative_+', 'Electrode positive or negative_0',
#        'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
#        'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
#        'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA',
#        'Yield strength / MPa'],
#       dtype='object')

# %%
x=yield_data_model[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
       'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
       'PC20', 'AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA']]
y=yield_data_model['Yield strength / MPa']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model =  SGDRegressor()
model.fit(X_train, y_train)
# Out:
# SGDRegressor()

# %%
# Prédire les valeurs sur l'ensemble de test
y_pred = model.predict(X_test)
# Évaluer les performances du modèle
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f'RMSE : {rmse:.2f}')
# Out:
# RMSE : 76.50

# %%
# Afficher les hyperparamètres du modèle
hyperparameters = model.get_params()
print("Hyperparamètres du modèle :")
for param, value in hyperparameters.items():
    print(f"{param}: {value}")
# Out:
# Hyperparamètres du modèle :
# alpha: 0.0001
# average: False
# early_stopping: False
# epsilon: 0.1
# eta0: 0.01
# fit_intercept: True
# l1_ratio: 0.15
# learning_rate: invscaling
# loss: squared_error
# max_iter: 1000
# n_iter_no_change: 5
# penalty: l2
# power_t: 0.25
# random_state: None
# shuffle: True
# tol: 0.001
# validation_fraction: 0.1
# verbose: 0
# warm_start: False

# %%
yield_data_test.columns
# Out:
# Index(['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
#        'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
#        'PC20', 'AC or DC_AC', 'AC or DC_DC',
#        'Electrode positive or negative_+', 'Electrode positive or negative_0',
#        'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
#        'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
#        'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA',
#        'Yield strength / MPa'],
#       dtype='object')

# %%
new_data=yield_data_test[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
       'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
       'PC20', 'AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA']]
pred=model.predict(new_data)

# %%
# Trouver les indices des valeurs manquantes
nan_indices = data_processed[data_processed['Yield strength / MPa'].isnull()].index

# Remplacer les valeurs manquantes avec les valeurs de 'pred'
data_processed.loc[nan_indices, 'Yield strength / MPa'] = pred

# %% [markdown]
# ### VII. Ultimate tensile strength / MPa

# %%
yield_data=data_processed[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
       'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
       'PC20', 'AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA',
       'Ultimate tensile strength / MPa']]

# %%
yield_data_test=yield_data[yield_data['Ultimate tensile strength / MPa'].isnull()]

# %%
yield_data_model = yield_data[yield_data['Ultimate tensile strength / MPa'].notnull()]

# %%
x=yield_data_model[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
       'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
       'PC20', 'AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA']]
y=yield_data_model['Ultimate tensile strength / MPa']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model =  SGDRegressor()
model.fit(X_train, y_train)
# Out:
# SGDRegressor()

# %%
# Prédire les valeurs sur l'ensemble de test
y_pred = model.predict(X_test)
# Évaluer les performances du modèle
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f'RMSE : {rmse:.2f}')
# Out:
# RMSE : 73.92

# %%
new_data=yield_data_test[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
       'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
       'PC20', 'AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA']]
pred=model.predict(new_data)

# %%
# Trouver les indices des valeurs manquantes
nan_indices = data_processed[data_processed['Ultimate tensile strength / MPa'].isnull()].index

# Remplacer les valeurs manquantes avec les valeurs de 'pred'
data_processed.loc[nan_indices, 'Ultimate tensile strength / MPa'] = pred

# %% [markdown]
# ### VII. Elongation / %

# %%
yield_data=data_processed[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
       'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
       'PC20', 'AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA',
       'Elongation / %']]
yield_data_test=yield_data[yield_data['Elongation / %'].isnull()]
yield_data_model = yield_data[yield_data['Elongation / %'].notnull()]
x=yield_data_model[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
       'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
       'PC20', 'AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA']]
y=yield_data_model['Elongation / %']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model =  SGDRegressor()
model.fit(X_train, y_train)
# Prédire les valeurs sur l'ensemble de test
y_pred = model.predict(X_test)
# Évaluer les performances du modèle
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f'RMSE : {rmse:.2f}')
new_data=yield_data_test[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
       'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
       'PC20', 'AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA']]
pred=model.predict(new_data)
# Trouver les indices des valeurs manquantes
nan_indices = data_processed[data_processed['Elongation / %'].isnull()].index

# Remplacer les valeurs manquantes avec les valeurs de 'pred'
data_processed.loc[nan_indices, 'Elongation / %'] = pred
# Out:
# RMSE : 4.30

# %% [markdown]
# ### VII. Reduction of area / %

# %%
yield_data=data_processed[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
       'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
       'PC20', 'AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA',
       'Reduction of Area / %']]
yield_data_test=yield_data[yield_data['Reduction of Area / %'].isnull()]
yield_data_model = yield_data[yield_data['Reduction of Area / %'].notnull()]
x=yield_data_model[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
       'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
       'PC20', 'AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA']]
y=yield_data_model['Reduction of Area / %']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model =  SGDRegressor()
model.fit(X_train, y_train)
# Prédire les valeurs sur l'ensemble de test
y_pred = model.predict(X_test)
# Évaluer les performances du modèle
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f'RMSE : {rmse:.2f}')
new_data=yield_data_test[['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10',
       'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19',
       'PC20', 'AC or DC_AC', 'AC or DC_DC',
       'Electrode positive or negative_+', 'Electrode positive or negative_0',
       'Type of weld_FCA', 'Type of weld_GTAA', 'Type of weld_MMA',
       'Type of weld_NGGMA', 'Type of weld_NGSAW', 'Type of weld_SA',
       'Type of weld_SAA', 'Type of weld_ShMA', 'Type of weld_TSA']]
pred=model.predict(new_data)
# Trouver les indices des valeurs manquantes
nan_indices = data_processed[data_processed['Reduction of Area / %'].isnull()].index

# Remplacer les valeurs manquantes avec les valeurs de 'pred'
data_processed.loc[nan_indices, 'Reduction of Area / %'] = pred
# Out:
# RMSE : 6.55

# %%
data_processed.isnull().any()
# Out:
# PC1                                 False
# PC2                                 False
# PC3                                 False
# PC4                                 False
# PC5                                 False
# PC6                                 False
# PC7                                 False
# PC8                                 False
# PC9                                 False
# PC10                                False
# PC11                                False
# PC12                                False
# PC13                                False
# PC14                                False
# PC15                                False
# PC16                                False
# PC17                                False
# PC18                                False
# PC19                                False
# PC20                                False
# AC or DC_AC                         False
# AC or DC_DC                         False
# Electrode positive or negative_+    False
# Electrode positive or negative_0    False
# Type of weld_FCA                    False
# Type of weld_GTAA                   False
# Type of weld_MMA                    False
# Type of weld_NGGMA                  False
# Type of weld_NGSAW                  False
# Type of weld_SA                     False
# Type of weld_SAA                    False
# Type of weld_ShMA                   False
# Type of weld_TSA                    False
# Yield strength / MPa                False
# Ultimate tensile strength / MPa     False
# Elongation / %                      False
# Reduction of Area / %               False
# dtype: bool

# %% [markdown]
# ## VII. Clustering quality

# %%
k= 6
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(data_processed[['Yield strength / MPa', 'Ultimate tensile strength / MPa','Elongation / %','Reduction of Area / %']])

# Ajouter les labels de cluster à vos données
data_processed['cluster_quality'] = kmeans.labels_
# Out:
# C:\Users\DF6610\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=7.
#   warnings.warn(

# %%
# Appliquer t-SNE pour réduire les dimensions à 2
quality_scaled = center_and_normalize(data_processed[['Yield strength / MPa', 'Ultimate tensile strength / MPa','Elongation / %','Reduction of Area / %']])
tsne = TSNE(n_components=2, random_state=42)
tsne_results = tsne.fit_transform(quality_scaled)

# Créer un DataFrame avec les résultats t-SNE et les clusters
tsne_df = pd.DataFrame(data=tsne_results, columns=['TSNE1', 'TSNE2'])
tsne_df['Cluster'] = kmeans.labels_

# Visualisation
plt.figure(figsize=(10, 6))
plt.scatter(tsne_df['TSNE1'], tsne_df['TSNE2'], c=tsne_df['Cluster'], cmap='viridis', marker='o', edgecolor='k', s=100)
plt.title('Clustering K-means avec t-SNE')
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.colorbar(label='Cluster')
plt.show()

# %%
df_pivot= pd.pivot_table(data_processed,values=['Yield strength / MPa', 'Ultimate tensile strength / MPa',
       'Elongation / %', 'Reduction of Area / %'],index=['cluster_quality'],aggfunc='mean')
df_pivot
# Out:
#                  Elongation / %  Reduction of Area / %  \
# cluster_quality
# 0                     29.794818              75.704746
# 1                     23.947863              66.758120
# 2                     28.093723              75.442036
# 3                     15.279084              50.697083
# 4                     21.222115              66.367408
# 5                     26.362194              71.695449
#
#                  Ultimate tensile strength / MPa  Yield strength / MPa
# cluster_quality
# 0                                     501.868977            405.759614
# 1                                     674.061780            569.852200
# 2                                     554.207897            467.618147
# 3                                     866.827393            777.062649
# 4                                     735.499667            650.704947
# 5                                     604.990724            514.835926

# %%
data_processed[['Yield strength / MPa', 'Ultimate tensile strength / MPa','Elongation / %','Reduction of Area / %']].describe()
# Out:
#        Yield strength / MPa  Ultimate tensile strength / MPa  Elongation / %  \
# count           1652.000000                      1652.000000     1652.000000
# mean             508.199695                       599.954115       26.367874
# std               90.774730                        91.185478        4.874067
# min              315.000000                       429.713825        7.111519
# 25%              452.551548                       538.655832       23.397307
# 50%              491.379120                       580.177889       27.100000
# 75%              543.335827                       636.328656       30.113949
# max              920.000000                      1151.000000       37.000000
#
#        Reduction of Area / %
# count            1652.000000
# mean               71.638019
# std                10.880829
# min               -22.251198
# 25%                66.785003
# 50%                75.000000
# 75%                78.800000
# max                84.518798

# %%
import seaborn as sns
import matplotlib.pyplot as plt
variables = ['Yield strength / MPa', 'Ultimate tensile strength / MPa',
             'Elongation / %', 'Reduction of Area / %']
# Ajouter une colonne pour la distribution globale
data_processed['cluster_global'] = 'Global'

# Combiner les colonnes 'cluster_quality' et 'cluster_global' pour obtenir une vue complète
data_with_global = pd.concat([data_processed[['cluster_quality'] + variables], 
                              data_processed[['cluster_global'] + variables].rename(columns={'cluster_global': 'cluster_quality'})])

# Liste des variables d'intérêt


# Création de sous-plots pour chaque variable
plt.figure(figsize=(15, 10))

for i, var in enumerate(variables, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x='cluster_quality', y=var, data=data_with_global)
    plt.title(f'Distribution of {var} by Cluster and Globally')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
